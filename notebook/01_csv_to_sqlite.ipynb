# %%
# CSV 파일을 SQLite 데이터베이스로 전환하는 함수 정의
import csv
import sqlite3
import re

def csv_to_sqlite(csv_filepath, db_filepath, table_name, drop_existing_table=False):
    """
    CSV 파일을 읽어 SQLite 데이터베이스로 전환합니다.

    Args:
        csv_filepath (str): 변환할 CSV 파일의 경로.
        db_filepath (str): 생성하거나 연결할 SQLite 데이터베이스 파일의 경로.
        table_name (str): 데이터를 삽입할 SQLite 테이블의 이름.
    """
    try:
        conn = sqlite3.connect(db_filepath)
        cursor = conn.cursor()

        # drop_existing_table이 True이면 기존 테이블 삭제
        if drop_existing_table:
            drop_table_sql = f"DROP TABLE IF EXISTS {table_name};"
            cursor.execute(drop_table_sql)
            print(f"기존 테이블 '{table_name}'이(가) 삭제되었습니다 (존재하는 경우).")
            conn.commit() # DROP TABLE 후에는 바로 커밋하여 반영

        with open(csv_filepath, 'r', encoding='utf-8') as f:
            reader = csv.reader(f)
            headers = next(reader)  # 첫 번째 행을 헤더로 읽음

            # SQL 컬럼 이름으로 유효하게 변환 (특수 문자 제거 및 공백 대체)
            cleaned_headers = [re.sub(r'\W+', '', header).strip().lower() for header in headers]
            
            # 테이블 생성 쿼리 구성
            # 모든 컬럼을 기본적으로 TEXT 타입으로 지정하여 유연성을 높입니다.
            # 필요에 따라 INSERT 전에 데이터 타입 변환 로직을 추가할 수 있습니다.
            columns_def = ', '.join([f"{header} TEXT" for header in cleaned_headers])
            create_table_sql = f"CREATE TABLE IF NOT EXISTS {table_name} ({columns_def});"
            cursor.execute(create_table_sql)
            print(f"테이블 '{table_name}'이(가) 생성되었거나 이미 존재합니다.")

            # 데이터 삽입 쿼리 구성
            placeholders = ', '.join(['?' for _ in cleaned_headers])
            insert_sql = f"INSERT INTO {table_name} ({', '.join(cleaned_headers)}) VALUES ({placeholders});"

            # 데이터 삽입
            for row_num, row in enumerate(reader, start=2): # 첫 번째 행은 헤더이므로 2부터 시작
                if len(row) != len(cleaned_headers):
                    print(f"경고: {row_num}행의 컬럼 개수가 헤더와 일치하지 않습니다. 이 행은 건너뜁니다: {row}")
                    continue
                try:
                    cursor.execute(insert_sql, row)
                except sqlite3.Error as e:
                    print(f"오류: {row_num}행을 삽입하는 중 오류가 발생했습니다: {row}. 오류 메시지: {e}")
                    continue # 오류 발생 시 해당 행은 건너뛰고 다음 행으로 진행

            conn.commit()
        print(f"'{csv_filepath}' 파일의 데이터가 '{db_filepath}'의 '{table_name}' 테이블로 성공적으로 전환되었습니다.")

    except FileNotFoundError:
        print(f"오류: '{csv_filepath}' 파일을 찾을 수 없습니다. 경로를 확인해 주세요.")
    except sqlite3.Error as e:
        print(f"SQLite 데이터베이스 오류: {e}")
    except Exception as e:
        print(f"예상치 못한 오류가 발생했습니다: {e}")
    finally:
        if 'conn' in locals() and conn:
            conn.close()

# %%
# CSV 파일을 SQLite 데이터베이스로 전환하는 함수 호출
csv_file = "../data/임베딩대상_202505261852.csv"
sqlite_db = "../.db/sqlite/my_database.db"
table = "PRODUCT"

csv_to_sqlite(csv_file, sqlite_db, table, True)

# 3. 데이터 확인 (선택 사항)
print("\n--- SQLite 데이터 확인 ---")
try:
    conn = sqlite3.connect(sqlite_db)
    cursor = conn.cursor()
    cursor.execute(f"SELECT * FROM {table};")
    rows = cursor.fetchall()
    for row in rows:
        print(row)
except sqlite3.Error as e:
    print(f"데이터 확인 중 오류 발생: {e}")
finally:
    if 'conn' in locals() and conn:
        conn.close()
# Out:
# 기존 테이블 'PRODUCT'이(가) 삭제되었습니다 (존재하는 경우).
# 테이블 'PRODUCT'이(가) 생성되었거나 이미 존재합니다.
# '../data/임베딩대상_202505261852.csv' 파일의 데이터가 '../.db/sqlite/my_database.db'의 'PRODUCT' 테이블로 성공적으로 전환되었습니다.
#
# --- SQLite 데이터 확인 ---
# ('0021216860', '엔산 EL-09 이젤형 TV스탠드 티비거치대', '정상상품', '엔산마운트', 'A/V 기타>TV 기타', '색상', '화이트 계열', 'TV·영상가전>TV>TV액세서리', 'N', '#TV거치대#TV브라켓#모니터거치대#모니터브라켓', '176000', '176000', '0', '', '', '176000')
# ('0026595956', '엔산 무드조명형 모니터암 블룸스탠드 삼텐바이미 거치대', '정상상품', '엔산마운트', 'A/V 기타>TV 기타', '', '', 'TV·영상가전>TV>TV액세서리', 'N', '#TV거치대#TV브라켓#모니터거치대#모니터브라켓', '140000', '140000', '0', '', '', '140000')
# ('0037357623', '5년무상AS 이스트라 120Hz AI 맥스 127cm UHD 구글 5.0 스마트TV (이젤스탠드A타입-기사)', '정상상품', '이스트라', 'TV>UHD TV', '크기,종류,해상도,응답속도,기본 주사율,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과,음향효과,지원단자', '50인치(127cm),LED,UHD(4K),6m/s,120Hz,구글플레이,넷플릭스,유튜브,크롬캐스트,구글어시스턴트,Disney+,블루투스,게임모드,플리커프리,HDMI CEC,HDMI 2.1 지원,HDMI eARC,크로마서브샘플링(4:4:4),USB재생(동영상·사진·음악),1등급,2025년,평면형,24W,돌비디지털Plus,돌비디지털,HDMI', 'TV·영상가전>TV>중형(~139cm)', 'Y', '#AN507UHD07', '588000', '588000', '0', '', '', '546840')
# ('0021376941', '2024년형 50인치 스마트 UHD 구글 TV 4K 에너지효율 1등급 T5003KUG 스탠드직배송', '정상상품', '루컴즈', 'TV>LED TV', '크기,종류,해상도,응답속도,기본 주사율,엔진,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과', '50인치(127cm),LED,UHD(4K),7m/s,60Hz,MT9612,넷플릭스,유튜브,크롬캐스트,구글어시스턴트,아마존프라임비디오,Disney+,AppleTV,USB재생,블루투스,플리커프리,HDMI ARC,HDMI CEC,HDMI 2.1 지원,HDMI eARC,크로마서브샘플링(4:4:4),1등급,2023년,평면형,20W,돌비애트모스', 'TV·영상가전>TV>중형(~139cm)', 'Y', '#50인치TV#50인치TV스마트#50인치uhd#50인치스마트TV#50인치티비#TV#스마트TV#티비', '439000', '439000', '0', '', '', '439000')
# ('0020478272', 'LG 218cm 4K UHD 디지털 사이니지  LED TV 86UM3E [설치유형 선택가능]', '정상상품', '아이티스토리', 'TV>LED TV', '', '', 'TV·영상가전>TV>초대형(190cm~)', 'Y', '', '2799000', '2799000', '0', '', '', '2799000')
# ('0021089184', '삼성 QLED 4K QC80 (163cm) TV 벽걸이형 KQ65QC80AFXKR(W)', '정상상품', '삼성전자', 'TV>QLEDTV', '크기,종류,해상도,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과,음향효과,지원단자,지원단자,지원단자,소비전력,VESA간격', '65인치(163cm),QLED,UHD(4K),넷플릭스,유튜브,음성인식,웨이브,알렉사,빅스비,Disney+,AppleTV,게임모드,HDMI ARC,HDMI CEC,HDMI eARC,4등급,2023년,평면형,40W,OTS,AI사운드최적화+,HDMI,LAN,Optical,295W,400*300mm', 'TV·영상가전>TV>대형(~189cm)', 'Y', '#163cm#4K#KQ65QC80AFXKR#QC80#QLED#TV#삼성', '3156000', '3156000', '0', '', '', '3156000')
# ('0021414021', '그랑데 의류건조기 DV90T5440KW 9kg 일반설치', '정상상품', '삼성전자', '세탁기>건조기', '건조 용량,건조방식,주요기능,주요기능,주요기능,e효율등급,색상,출시년도', '9kg,히트펌프식,AI건조,타이머,구김방지,1등급,화이트 계열,2020년', '세탁기·건조기·의류관리기>건조기·탈수기>건조기', 'Y', '#DV90T5440KW_S', '1248600', '1123740', '5', '롯데카드', '롯데카드,네이버페이,삼성카드', '1067550')
# ('0020935216', '146cm UHD TV KU58UC7000FXKR 스탠드형', '정상상품', '삼성전자', 'TV>UHD TV', '크기,종류,해상도,엔진,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과,지원단자,지원단자', '58인치(146cm),LED,UHD(4K),크리스탈프로세서,넷플릭스,유튜브,웨이브,알렉사,아마존프라임비디오,Disney+,AppleTV,왓챠플레이,쿠팡플레이,USB재생,Q심포니,게임모드,HDMI ARC,HDMI CEC,HDMI eARC,1등급,2023년,평면형,20W,OTS Lite,HDMI,LAN', 'TV·영상가전>TV>대형(~189cm)', 'Y', '#KU58UC7000FXKR_SS', '1160000', '1160000', '5', '롯데카드', '롯데카드,현대카드,네이버페이,삼성카드,신한카드,KB국민카드', '1102000')
# ('0020966106', '146cm UHD TV KU58UC7000FXKR [설치유형 선택가능]', '정상상품', '삼성전자', 'TV>UHD TV', '', '', 'TV·영상가전>TV>대형(~189cm)', 'Y', '', '1160000', '1160000', '5', '롯데카드', '롯데카드,현대카드,네이버페이,삼성카드,신한카드,KB국민카드', '1102000')
# ('0021880077', '24년형 신제품 이스트라 144Hz VRR 65 UHD AI 구글TV 벽걸이 상하(', '정상상품', '이스트라', 'TV>NLEDTV', '크기,종류,해상도,응답속도,기본 주사율,엔진,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력', '65인치(164cm),LED,UHD(4K),6m/s,120Hz,MT9617,구글플레이,넷플릭스,유튜브,인터넷,음성인식,크롬캐스트,구글어시스턴트,Disney+,블루투스,게임모드,플리커프리,HDMI CEC,HDMI 2.1 지원,HDMI eARC,크로마서브샘플링(4:4:4),USB재생(동영상·사진·음악),2등급,2024년,평면형,24W', 'TV·영상가전>TV>대형(~189cm)', 'Y', '#65인치TV#65인치티비#TV#스마트TV#스마트티비#안드로이드TV#안드로이드티비#중소기업TV#중소기업티비#티비', '2010000', '2010000', '0', '', '', '2010000')
# ('0029492162', '로보락 세탁 1kg+건조 0.5kg 컴팩트 올인원 세탁건조기 M1/매일빨래/세제자동투입/먼지통 자동세척/UVC살균', '정상상품', '로보락', '세탁기>드럼 세탁기', '종류,세탁 용량,스마트기능,스마트기능,스마트기능,스마트기능,색상,세탁코스,모터 종류', '소형,1kg,세제자동투입,스마트케어,자외선살균,잠금기능,화이트 계열,스포츠웨어,DD모터/히트펌프', '세탁기·건조기·의류관리기>세탁기+건조기|세탁기·건조기·의류관리기>드럼세탁기', 'Y', '#로보락#세탁기#H1#M1#건조기#세탁건조기#콤보#콤보워시#올인원', '749000', '749000', '0', '', '', '599000')
# ('0017034678', '138cm QLED안드로이드 스마트TV UG551QLED(기본스탠드 기사설치)', '정상상품', '더함', 'TV>QLEDTV', '크기,종류,해상도,응답속도,기본 주사율,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,지원단자,지원단자,지원단자,소비전력', '55인치(138cm),QLED,UHD(4K),6m/s,120Hz,구글플레이,넷플릭스,유튜브,음성인식,구글어시스턴트,Disney+,USB재생,블루투스5.0,HDMI 2.0 지원,HDMI CEC,HDMI 2.1 지원,HDMI eARC,크로마서브샘플링(4:4:4),3등급,2022년,평면형,36W,HDMI,LAN,Optical,180W', 'TV·영상가전>TV>중형(~139cm)', 'Y', '#55인치TV#qledtv#스마트TV#안드로이드TV#중소기업TV#티비', '629000', '629000', '0', '', '', '629000')
# ('0026413265', '[오늘 주문하면 바로 배송! ] 삼성전자 24년형 비지니스TV LH65BEDHLGFXKR 4K UHD 163cm 스탠드형 기사설치제품', '정상상품', '삼성전자', 'TV>UHD TV', '크기,종류,해상도,응답속도,엔진,스마트기능,스마트기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과,지원단자,소비전력,색상,HDMI 포트수,USB 포트수,두께,무게,패널 종류,TV 설치 유형', '60~69인치,LED,UHD(4K),~5m/s 미만,크리스탈프로세서,유튜브,인터넷,블루투스,1등급,2024년,평면형,20~30W 미만,OTS Lite,HDMI,100~200W미만,블랙 계열,3포트,1포트,2~4cm 미만,10~20kg 미만,삼성패널,스탠드형', 'TV·영상가전>TV>대형(~189cm)', 'Y', '#LH65BED', '819000', '819000', '0', '', '', '819000')
# ('0026418802', '삼성전자 24년형 비지니스TV LH65BEDHLGFXKR 4K UHD 163cm 기사설치제품 (설치유형 선택가능) ', '정상상품', '삼성전자', 'TV>UHD TV', '', '', 'TV·영상가전>TV>대형(~189cm)', 'Y', '', '819000', '819000', '0', '', '', '819000')
# ('0020615558', '비스포크 에어드레서 의류관리기 DF24CB9900AR', '정상상품', '삼성전자', '세탁기>의류관리기', '용량,살균기능,부가기능,부가기능,부가기능,색상,출시년도', '상의5벌+하의5벌,바이러스,다운로드코스,스마트폰페어링,미러도어,핑크 계열,2023년', '세탁기·건조기·의류관리기>의류관리기>에어드레서', 'Y', '#DF24CB9900AR_S', '3240000', '2916000', '5', '롯데카드', '롯데카드,네이버페이,삼성카드', '2770200')
# ('0022821052', '190cm 5년무상AS 초고화질 이스트라 144Hz AI 75 QD- Mini LED 퀀텀사운드 구글TV (이동형타입A/기사방문)', '정상상품', '이스트라', 'TV>LED TV', '크기,종류,해상도,응답속도,기본 주사율,엔진,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과', '75인치(190cm),LED,UHD(4K),6m/s,144Hz,MT9617,구글플레이,넷플릭스,유튜브,인터넷,크롬캐스트,구글어시스턴트,블루투스,게임모드,플리커프리,HDMI CEC,HDCP 2.2 지원,HDMI 2.1 지원,HDMI eARC,크로마서브샘플링(4:4:4),USB재생(동영상·사진·음악),3등급,2024년,평면형,50W,돌비디지털Plus', 'TV·영상가전>TV>초대형(190cm~)', 'Y', '#65인치TV#65인치티비#TV#미니LEDTV#미니LED티비#스마트TV#스마트티비#안드로이드TV#안드로이드티비#중소기업TV#중소기업티비#티비', '1508000', '1508000', '0', '', '', '1402440')
# ('0043296350', '[상급] 비스포크 에어드레서 의류관리기 DF24CB9900NR', '진열상품', '삼성전자', '세탁기>의류관리기', '', '', '세탁기·건조기·의류관리기>의류관리기>에어드레서|세탁기·건조기·의류관리기>전시상품>의류관리기|전문가 화상상담>대형가전>의류관리기', 'Y', '#에어드레서#의류관리기#삼성에어드레서#DF24CB9900NR#전시상품', '2070000', '1367700', '0', '', '', '1367700')
# ('0020916568', '카멜 108cm CDS4320SR 스탠드형DID 광고용모니터 가로세로 전환', '정상상품', '카멜', '모니터>LED 일반', '응답속도', '8m/s', 'TV·영상가전>영상가전>디지털액자', 'Y', '#광고모니터#광고콘텐#디지털메뉴판#스탠드모니터#웰컴보드#전자게시판#전자메뉴판#홍보모니터#홍보용모니터', '1554000', '1554000', '10', '롯데카드', '롯데카드,현대카드,네이버페이,삼성카드,신한카드,KB국민카드', '1398600')
# ('0019954964', '18kg 통돌이세탁기 T18DX7', '정상상품', 'LG전자', '세탁기>일반세탁기', '종류,세탁 용량,스마트기능,스마트기능,스마트기능,스마트기능,e효율등급,색상,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,출시년도,모터 종류', '일반,18kg,코스다운로드,휴대폰진단,에너지모니터링,통세척,2등급,실버 계열,컬러케어,헹굼+탈수,울,표준,청바지,섬세,소량/쾌속,란제리,수영복,장마철세탁,탈수전용,2022년,인버터 DD모터', '세탁기·건조기·의류관리기>일반세탁기', 'Y', '#T18DX7#18키로#LG#엘지#통돌이세탁기18k', '713000', '648830', '0', '', '', '648830')
# ('0020622292', '카멜 20cm PF8050BP IPS패널 광시야각 충전식 거치대패키지 디지털액자', '정상상품', '카멜', '모니터>LED 일반', '', '', 'TV·영상가전>영상가전>디지털액자', 'Y', '#8인치모니터#광고용모니터#디지털액자#모니터#모니터추천#액자#행사용모니터', '112900', '112900', '10', '롯데카드', '롯데카드,현대카드,네이버페이,삼성카드,신한카드,KB국민카드', '101610')
# ('0026967940', '[벽걸이형]삼성전자 LH85BEDHLGF 215Cm 4K UHD HDR10+ 1등급 비지니스 TV', '정상상품', '삼성전자', 'TV>LED TV', '크기,종류,해상도,기본 주사율,엔진,스마트기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과,지원단자,지원단자,지원단자,소비전력,VESA간격,색상,HDMI 포트수,USB 포트수,두께,무게,TV 설치 유형', '80인치 이상,LED,UHD(4K),60Hz,퀀텀프로세서,유튜브,블루투스,1등급,2024년,평면형,10~20W 미만,OTS Lite,HDMI,RF,LAN,200~300W미만,600*400mm,블랙 계열,3포트,1포트,6cm이상~,30~40kg 미만,벽걸이형', 'TV·영상가전>TV>초대형(190cm~)', 'Y', '#4K#85인치#TV#UHD#광고#비지니스#회사#회의', '1730000', '1730000', '7', '롯데카드', '롯데카드,현대카드,네이버페이,삼성카드,신한카드,KB국민카드', '1608900')
# ('0042609092', '[5년무상AS]플럭스 139cm(55인치) UHD TV (벽걸이형)', '정상상품', 'PLUX', 'TV>UHD TV', '크기,종류,해상도,응답속도,기본 주사율,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과,지원단자,지원단자', '55인치(139cm),LED,UHD(4K),5m/s,60Hz,구글플레이,넷플릭스,유튜브,인터넷,크롬캐스트,구글어시스턴트,아마존프라임비디오,블루투스,HDMI 2.0 지원,HDMI ARC,HDMI CEC,HDCP 2.2 지원,크로마서브샘플링(4:4:4),USB재생(동영상·사진·음악),1등급,2025년,평면형,20W,돌비디지털Plus,HDMI,RF', 'TV·영상가전>TV>중형(~139cm)|PLUX 전문관>TV', 'Y', '', '849000', '849000', '0', '', '', '849000')
# ('0019332474', '애니빔 스마트 빔프로젝터 WFA-400', '정상상품', '애니게이트', 'A/V 기타>프로젝터', '방식,해상도,스마트 기능,스마트 기능,스마트 기능,밝기(루멘),밝기(안시),단자,단자,소음,스피커출력,부가기능,부가기능', 'LCD,FHD급,안드로이드,유튜브,넷플릭스,9500루멘,450안시,HDMI,USB,58dB,10W,블루투스,WiFI', 'TV·영상가전>영상가전>빔프로젝터', 'Y', '#미니빔#홈시네마#빔프로젝터#가정용빔프로젝터#캠핑용빔프로젝터#회의용빔#', '269000', '269000', '7', '롯데카드', '롯데카드,현대카드,삼성카드', '250170')
# ('0021017542', '하이메이드 127cm(50인치) UHD TV HMDT50G4UBS (설치유형 선택가능)', '정상상품', '하이메이드', 'TV>UHD TV', '', '', 'TV·영상가전>TV>중형(~139cm)|전문가 화상상담>대형가전>TV', 'Y', '', '599000', '599000', '0', '', '', '599000')
# ('0042096955', '비스프링 TV 스탠드 대형', '정상상품', '비스프링', '사무용품', '', '', 'TV·영상가전>TV>TV액세서리', 'N', '#TV스탠드', '508000', '447040', '5', '롯데카드', '롯데카드,현대카드,현대카드,삼성카드,신한카드,KB국민카드', '424690')
# ('0020218806', '비스포크 그랑데AI 25kg 드럼 세탁기 WF25CB8895BW [올인원 컨트롤]', '정상상품', '삼성전자', '세탁기>드럼 세탁기', '종류,세탁 용량,e효율등급,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,색상,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,출시년도', '드럼,25kg,1등급,세제자동투입,스마트컨트롤,통세척,자동문열림,잠금기능,화이트 계열,헹굼+탈수,타월,울,표준,블라우스,아웃도어,AI맞춤세탁,면,섬세,쾌속,아기옷,펫케어세탁,탈수단독,2023년', '세탁기·건조기·의류관리기>드럼세탁기|전문가 화상상담>대형가전>세탁기', 'Y', '#삼성드럼세탁기#25kg드럼세탁기#비스포크세탁기#세탁기#WF25CB8895BW#1등급세탁기', '1990000', '1990000', '5', '롯데카드', '롯데카드,현대카드,삼성카드', '1890500')
# ('0045690772', '[상급] 217cm 나노셀 NLED TV 86NANO75KQA 스탠드형', '진열상품', 'LG전자', 'TV>NLEDTV', '', '', 'TV·영상가전>TV>초대형(190cm~)|TV·영상가전>전시상품>TV|전문가 화상상담>대형가전>TV', 'Y', '#86인치#4KUHD#TV#티비#전시상품', '3390000', '2390000', '0', '', '', '2390000')
# ('0019851225', '삼성 165cm NEO QLED 4K UHD TV 65QN85A 설치유형 선택가능', '정상상품', 'MIDOTECH', 'TV>네오QLEDTV', '', '', 'TV·영상가전>TV>대형(~189cm)', 'Y', '#65인치#TV', '1799000', '1799000', '0', '', '', '1799000')
# ('0020637497', 'LH43BECHLGF 108Cm(43) 비지니스 TV/ 벽걸이형 / 4K UHD/LED', '정상상품', '삼성전자', 'TV>LED TV', '크기,종류,해상도,엔진,스마트기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,지원단자,지원단자,지원단자,지원단자,소비전력,색상,HDMI 포트수,USB 포트수,무게,TV 설치 유형', '43인치(108cm),LED,UHD(4K),크리스탈프로세서,유튜브,USB재생,블루투스4.2,1등급,2023년,평면형,HDMI,RF,LAN,Optical,125W,블랙 계열,3포트,1포트,7.7kg,벽걸이형', 'TV·영상가전>TV>중소형(~109cm)', 'Y', '#4K#LED#TV#가성비#간판#광고#무대#배너#비지니스#사무실#삼성전자#행사#회의', '514000', '514000', '7', '롯데카드', '롯데카드,현대카드,네이버페이,삼성카드,신한카드,KB국민카드', '478020')
# ('0021472642', '189cm UHD TV KU75UD8070FXKR 벽걸이형', '정상상품', '삼성전자', 'TV>UHD TV', '크기,종류,해상도,기본 주사율,엔진,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과,음향효과,지원단자,지원단자,지원단자,소비전력', '75인치(189cm),LED,UHD(4K),60Hz,크리스탈프로세서,넷플릭스,유튜브,음성인식,빅스비,USB재생,블루투스,Q심포니,게임모드,HDMI ARC,HDMI CEC,HDMI eARC,1등급,2024년,평면형,20W,AI사운드최적화,OTS Lite,HDMI,LAN,Optical,255W', 'TV·영상가전>TV>대형(~189cm)', 'Y', '#KU75UD8070FXKR_SM', '4374400', '4374400', '5', '롯데카드', '롯데카드,현대카드,네이버페이,삼성카드,신한카드,KB국민카드', '4174400')
# ('0027874617', '삼성 Crystal UHD TV 189cm 벽걸이형 KU75UD8070FXKR(W)', '정상상품', '삼성전자', 'TV>UHD TV', '크기,종류,해상도,기본 주사율,엔진,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과,지원단자', '75인치(189cm),LED,UHD(4K),60Hz,크리스탈프로세서,넷플릭스,유튜브,구글어시스턴트,웨이브,빅스비,아마존프라임비디오,Disney+,AppleTV,쿠팡플레이,USB재생,블루투스,Q심포니,게임모드,HDMI CEC,HDMI eARC,1등급,2024년,평면형,20W,OTS Lite,HDMI', 'TV·영상가전>TV>초대형(190cm~)', 'Y', '#189cm#Crystal#KU75UD8070FXKR(W)#TV#UHD#벽걸이형#삼성', '2340000', '2340000', '0', '', '', '2340000')
# ('0022163684', '[중급 / 덕소롯데마트점] 삼성전자 5벌형 에어드레서 DF10B9500SG', '진열상품', '삼성전자', '세탁기>의류관리기', '', '', '세탁기·건조기·의류관리기>의류관리기>에어드레서', 'Y', '#bespoke#의류관리기#대용량#안심케어#비스포크#BESPOKE#에어드레서#전시상품', '1960000', '957500', '0', '', '', '957500')
# ('0022165007', '[중급] 삼성전자 5벌형 에어드레서 DF10B9500SG', '진열상품', '삼성전자', '세탁기>의류관리기', '', '', '세탁기·건조기·의류관리기>의류관리기>에어드레서|세탁기·건조기·의류관리기>전시상품>의류관리기|안심케어>가전 보험>전시가전수리비보험', 'Y', '#bespoke#의류관리기#대용량#안심케어#비스포크#BESPOKE#에어드레서#전시상품', '1960000', '957500', '0', '', '', '957500')
# ('0037358260', '5년무상AS 이스트라 120Hz AI 맥스 139cm QLED 구글 5.0 스마트TV (스탠드형설치-기사방문)', '정상상품', '이스트라', 'TV>QLEDTV', '크기,종류,해상도,응답속도,기본 주사율,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과,음향효과', '55인치(139cm),QLED,UHD(4K),6m/s,120Hz,구글플레이,넷플릭스,유튜브,크롬캐스트,구글어시스턴트,Disney+,블루투스,게임모드,플리커프리,HDMI CEC,HDCP 2.2 지원,HDMI 2.1 지원,HDMI eARC,크로마서브샘플링(4:4:4),USB재생(동영상·사진·음악),1등급,2025년,평면형,24W,돌비디지털Plus,돌비디지털', 'TV·영상가전>TV>중형(~139cm)', 'Y', '#55인치TV#55인치티비#TV#구글5.0#스마트TV#스마트티비#안드로이드TV#안드로이드티비#중소기업TV#중소기업티비#티비', '556000', '556000', '0', '', '', '517080')
# ('0019984626', 'LG 트롬 15kg 드럼 세탁기 F15WQWP', '정상상품', 'LG전자', '세탁기>드럼 세탁기', '종류,세탁 용량,e효율등급,스마트기능,스마트기능,스마트기능,스마트기능,색상,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,출시년도,모터 종류', '드럼,15kg,1등급,코스다운로드,휴대폰진단,에너지모니터링,원격제어,화이트 계열,찌든때,조용조용,컬러케어,헹굼+탈수,찬물세탁,울,표준,와이셔츠,아기옷,란제리,기능성의류,옷감보호,장마철세탁,탈수전용,2022년,인버터 DD모터', '세탁기·건조기·의류관리기>드럼세탁기', 'Y', '#15kg#15kg드럼세탁기#F15WQWP#LG#LG트롬#드럼#세탁기#엘지세탁기#트롬#f15wq#엘지드럼세탁기15키로사이즈', '716600', '630610', '5', '롯데카드', '롯데카드,네이버페이,삼성카드', '599080')
# ('0021401401', '108cm Lifestyle TV KQ43LSD03AFXKR 벽걸이형', '정상상품', '삼성전자', 'TV>QLEDTV', '크기,종류,해상도,기본 주사율,엔진,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과,음향효과,음향효과,지원단자,지원단자,지원단자,소비전력,VESA간격', '43인치(108cm),QLED,UHD(4K),60Hz,퀀텀프로세서,넷플릭스,유튜브,구글어시스턴트,빅스비,USB재생,블루투스,게임모드,HDMI CEC,HDMI eARC,4등급,2024년,평면형,20W,AI사운드최적화,OTS Lite,돌비애트모스,HDMI,LAN,Optical,145W,200*200mm', 'TV·영상가전>TV>중소형(~109cm)|전문가 화상상담>대형가전>TV|전문가 화상상담>안심케어>가전교체서비스', 'Y', '#TV#삼성TV#43인치TV#라이프스타일TV', '1690000', '1690000', '7', '롯데카드', '롯데카드,현대카드,삼성카드', '1571700')
# ('0022064807', 'LG 218cm 4K UHD TV 스마트 티비 86UQ7070 리퍼 지방스탠드', '정상상품', 'MIDOTECH', 'TV>UHD TV', '크기,종류,해상도,엔진,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,출시년도,화면 타입,스피커 출력,지원단자,지원단자,지원단자,색상,HDMI 포트수,USB 포트수,패널 종류,TV 설치 유형', '86인치(218cm),LED,UHD(4K),알파5 Gen5,넷플릭스,유튜브,인터넷,웨이브,에어플레이2,왓챠플레이,USB재생,블루투스5.0,게임모드,스포츠알람,2022년,평면형,20W,HDMI,LAN,Optical,블랙 계열,2포트,1포트,IPS패널,스탠드형+벽걸이형', 'TV·영상가전>TV>초대형(190cm~)', 'Y', '#4K#86인치#LG#LGTV#UHD#리퍼TV#리퍼티비#스마트TV#엘지티비', '1789000', '1789000', '0', '', '', '1789000')
# ('0021001751', '일반세탁기 6.5KG  HLJ-W065', '정상상품', '하이메이드', '세탁기>일반세탁기', '종류,세탁 용량,스마트기능,스마트기능,e효율등급,색상,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,출시년도', '일반,6.5kg,통세척,잠금기능,3등급,화이트 계열,헹굼+탈수,표준,합성섬유,강력,불림,쾌속,탈수전용,2023년', '세탁기·건조기·의류관리기>일반세탁기|전문가 화상상담>대형가전>세탁기', 'Y', '#하이메이드#하이메이드세탁기#일반세탁기#세탁기#6KG세탁기#6.5KG세탁기', '319000', '319000', '0', '', '', '319000')
# ('0021344931', '125cm UHD TV DK5001US 각도조절형 벽걸이', '정상상품', '대우디스플레이', 'TV>UHD TV', '크기,종류,해상도,응답속도,기본 주사율,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과,지원단자,지원단자,지원단자,지원단자,소비전력,색상,HDMI 포트수,USB 포트수,두께,무게,패널 종류', '50인치(125cm),LED,UHD(4K),5m/s,60Hz,HDMI ARC,HDMI CEC,UHD업스케일,크로마서브샘플링(4:4:4),USB재생(동영상·사진·음악),1등급,2023년,평면형,20W,돌비디지털Plus,컴포넌트,HDMI,RF,Optical,90W,블랙 계열,1포트,1포트,7.7cm,8.6kg,광시야각', 'TV·영상가전>TV>중형(~139cm)|전문가 화상상담>대형가전>TV', 'Y', '#대우TV#UHDTV#TV#스탠드형TV', '649000', '649000', '7', '롯데카드', '롯데카드,현대카드,삼성카드', '603570')
# ('0024863010', 'CP65G3MG 165cm QD-Mini LED 사운드바 일체형 144Hz 구글 스마트TV (기사방문/벽걸이설치)', '정상상품', '프리즘코리아', 'TV>QLEDTV', '크기,종류,해상도,응답속도,기본 주사율,엔진,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입', '65인치(165cm),QLED,UHD(4K),6ms,144Hz,MT9617,구글플레이,넷플릭스,유튜브,크롬캐스트,구글어시스턴트,웨이브,아마존프라임비디오,Disney+,AppleTV,왓챠플레이,쿠팡플레이,USB재생,블루투스,HDMI ARC,HDMI CEC,HDMI 2.1 지원,HDMI eARC,1등급,2024년,평면형', 'TV·영상가전>TV>대형(~189cm)', 'Y', '#65인치#QLED#게이밍TV#미니LED#벽걸이TV#스마트TV', '1149000', '1149000', '10', '롯데카드', '롯데카드,현대카드,네이버페이,삼성카드,신한카드,KB국민카드', '1034100')
# ('0034322220', '127cm UHD TV DT50A3UB 각도고정 벽걸이형', '정상상품', '대우디스플레이', 'TV>UHD TV', '크기,종류,해상도,응답속도,기본 주사율,부가기능,부가기능,부가기능,부가기능,e효율등급,스피커 출력,지원단자,지원단자,지원단자,지원단자,지원단자,소비전력,색상,무게,TV 설치 유형', '127cm,LED,UHD(4K),5m/s,60Hz,HDMI 2.0 지원,HDCP 2.2 지원,크로마서브샘플링(4:4:4),USB재생(동영상·사진·음악),1등급,20W,컴포넌트,헤드폰단자,HDMI,RF,Optical,100W,블랙 계열,9.1kg,벽걸이형', 'TV·영상가전>TV>중형(~139cm)', 'Y', '#50인치#대우TV#TV#50인치TV#UHDTV#UHD4KTV#TV추천#가성비TV#게임용TV#슬림TV#베스트TV#인기많은TV#최다판매TV#1등급TV', '649000', '649000', '7', '롯데카드', '롯데카드,현대카드,삼성카드', '603570')
# ('0013143793', '드럼세탁기용 배수호스', '정상상품', '유성', '백색/생활보조>세탁기보조', '', '', '생활·주방용품>생활용품>세탁용품|소모품 전문관>대형가전>세탁기 급수/배수 호스', 'Y', '', '7300', '7300', '0', '', '', '7300')
# ('0020615554', '비스포크 에어드레서 의류관리기 DF18CB8600WR', '정상상품', '삼성전자', '세탁기>의류관리기', '용량,살균기능,부가기능,부가기능,색상,출시년도', '상의5벌+하의1벌,바이러스,다운로드코스,스마트폰페어링,화이트 계열,2023년', '세탁기·건조기·의류관리기>의류관리기>에어드레서', 'Y', '#DF18CB8600WR_S', '2314500', '2083050', '5', '롯데카드', '롯데카드,네이버페이,삼성카드', '1978900')
# ('0023066989', '[상급 / 소사점] 삼성전자 Neo QLED TV KQ75QNC88AFXKR', '진열상품', '삼성전자', 'TV>네오QLEDTV', 'e효율등급', '3등급', 'TV·영상가전>TV>초대형(190cm~)|전문가 화상상담>대형가전>TV|전문가 화상상담>안심케어>가전교체서비스', 'Y', '#75인치#75인치TV#Neo#QLED#QLEDTV#QLEDTV#삼성TV#삼성#TV#티비#kq75qn#전시상품', '2100000', '1975900', '0', '', '', '1975900')
# ('0045280655', 'UHD TV 65NANO90AKA 벽걸이형', '정상상품', 'LG전자', 'TV>UHD TV', '크기,종류,해상도,기본 주사율,e효율등급,출시년도,소비전력,TV 설치 유형', '60~69인치,LED,UHD(4K),60Hz,1등급,2025년,100~200W미만,스탠드형+벽걸이형', 'TV·영상가전>TV>대형(~189cm)', 'Y', '#65NANO90AKA_SM', '2100000', '2100000', '0', '', '', '2100000')
# ('0020483306', '163cm 울트라 TV 65UR9300KNA 벽걸이형', '정상상품', 'LG전자', 'TV>UHD TV', '크기,종류,해상도,기본 주사율,엔진,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과,음향효과,지원단자,지원단자,지원단자,지원단자,소비전력', '65인치(163cm),LED,UHD(4K),60Hz,알파5 Gen6,인터넷,스마트리모컨,음성인식,구글어시스턴트,에어플레이2,USB재생,블루투스5.0,스포츠알람,HDMI 2.0 지원,HDMI eARC,1등급,2023년,평면형,20W,공간인식사운드,인공지능사운드,HDMI,RF,LAN,Optical,195W', 'TV·영상가전>TV>대형(~189cm)', 'Y', '#65인치#65인치TV#UHD#LGTV#LG#TV#티비#스마트#4KUHD', '1940000', '1940000', '7', '롯데카드', '롯데카드,현대카드,삼성카드', '1804200')
# ('0044219704', 'LG 통돌이 세탁기 16kg TR16MK2', '정상상품', 'LG전자', '세탁기>일반세탁기', 'e효율등급', '2등급', '세탁기·건조기·의류관리기>일반세탁기', 'Y', '#16kg#16kg세탁기#LG#LG세탁기#TR16MK2#세탁기#엘지세탁기#통돌이#통돌이세탁기', '501100', '456000', '0', '', '', '456000')
# ('0018601622', 'LG 127cm 4K UHD 21년 최신 스마트 TV 50UP7560 리퍼 설치유형 선택가능', '정상상품', 'MIDOTECH', 'TV>UHD TV', '', '', 'TV·영상가전>TV>중형(~139cm)', 'Y', '#TV', '579000', '579000', '0', '', '', '579000')
# ('0022893793', '218cm 5년무상AS 초고화질 144Hz 86 QD-Mini LED AI 퀀텀사운드 이스트라 쿠카 구글 스마트TV(벽걸이상하/기사방문)', '정상상품', '이스트라', 'TV>UHD TV', '크기,종류,해상도,응답속도,기본 주사율,엔진,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,출시년도,화면 타입,스피커 출력,음향효과,음향효과', '86인치(218cm),LED,UHD(4K),6m/s,144Hz,MT9617,구글플레이,넷플릭스,유튜브,인터넷,크롬캐스트,구글어시스턴트,블루투스,게임모드,플리커프리,HDMI CEC,HDCP 2.2 지원,HDMI 2.1 지원,HDMI eARC,크로마서브샘플링(4:4:4),USB재생(동영상·사진·음악),2024년,평면형,50W,돌비디지털Plus,돌비디지털', 'TV·영상가전>TV>초대형(190cm~)', 'Y', '#UC863MLED02', '2083000', '2083000', '0', '', '', '1937190')
# ('0019411084', 'LG 울트라HD TV 138cm 스탠드형 55UR642S0NC', '정상상품', 'LG전자', 'TV>LED TV', '크기,종류,해상도,기본 주사율,엔진,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과,지원단자,지원단자,지원단자,소비전력,색상,HDMI 포트수,USB 포트수,무게,패널 종류,TV 설치 유형', '55인치(138cm),LED,UHD(4K),60Hz,알파7 Gen4,유튜브,USB재생,블루투스,사운드싱크,게임모드,HDMI eARC,1등급,2021년,평면형,20W,인공지능사운드,HDMI,LAN,Optical,160W,블랙 계열,3포트,1포트,14kg,광시야각,스탠드형', 'TV·영상가전>TV>중형(~139cm)', 'Y', '#138cm#55UR642SS#LG#TV#스탠드형#울트라HD#55인치#4KUHD#티비#엘지', '741900', '741900', '0', '', '', '741900')
# ('0019411090', '138cm LG 울트라HD TV  55UR642S0NC (설치유형 선택가능)', '정상상품', 'LG전자', 'TV>LED TV', '', '', 'TV·영상가전>TV>중형(~139cm)', 'Y', '#55인치#4KUHD#TV#티비#엘지#lg전자', '741900', '741900', '0', '', '', '741900')
# ('0022415330', '163cm QLED 4K KQ65QCE1AFXKR 벽걸이형', '정상상품', '삼성전자', 'TV>QLEDTV', '크기,종류,해상도,기본 주사율,엔진,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과,음향효과,지원단자,지원단자,지원단자,소비전력', '65인치(163cm),QLED,UHD(4K),60Hz,퀀텀프로세서4K Lite,넷플릭스,유튜브,인터넷,빅스비,USB재생,블루투스,Q심포니,게임모드,HDMI ARC,HDMI CEC,HDMI eARC,1등급,2023년,평면형,20W,AI사운드최적화,OTS Lite,HDMI,LAN,Optical,170W', 'TV·영상가전>TV>대형(~189cm)|전문가 화상상담>대형가전>TV', 'Y', '#65인치#삼성TV#TV#65인치TV#QLEDTV#QLED', '1590000', '1590000', '7', '롯데카드', '롯데카드,현대카드,삼성카드', '1478700')
# ('0020219345', '비스포크 에어드레서 의류관리기 DF24CB9900ER', '정상상품', '삼성전자', '세탁기>의류관리기', '용량,살균기능,부가기능,색상,출시년도', '상의5벌+하의5벌,미세먼지,원격제어,베이지계열,2023년', '세탁기·건조기·의류관리기>의류관리기>에어드레서|전문가 화상상담>대형가전>의류관리기', 'Y', '#에어드레서#의류관리기#삼성에어드레서#DF24CB9900ER', '1800000', '1800000', '5', '롯데카드', '롯데카드,현대카드,삼성카드', '1710000')
# ('0035750809', '214cm QLED 4K KQ85QD60AFXKR 벽걸이형', '정상상품', '삼성전자', 'TV>QLEDTV', '크기,종류,해상도,기본 주사율,엔진,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과,음향효과,지원단자,지원단자,지원단자', '85인치(214cm),QLED,UHD(4K),60Hz,퀀텀프로세서4K Lite,넷플릭스,유튜브,음성인식,구글어시스턴트,빅스비,USB재생,블루투스,Q심포니,게임모드,HDMI ARC,HDMI CEC,HDMI eARC,1등급,2024년,평면형,20W,AI사운드최적화,OTS Lite,HDMI,LAN,Optical', 'TV·영상가전>TV>초대형(190cm~)', 'Y', '#85인치#삼성TV#TV#85인치TV#QLEDTV#QLED#4KTV#TV추천#스마트TV#가성비TV#게이밍TV#게임용TV#슬림TV#베스트TV#인기많은TV#최다판매TV#홈시네마#1등급TV#TV할인#넷플릭스TV#60HzTV#무빙사운드#영화TV#극장TV#대형TV#KQ85QD60AFXKR벽걸이형HW-C400', '2349000', '2349000', '10', '롯데카드', '롯데카드,현대카드,네이버페이,삼성카드,신한카드,KB국민카드', '2199000')
# ('0041468782', 'LG 190cm(75) 4K UHD 유튜브 넷플릭스 스마트TV 75UT7550 미사용리퍼 서울경기벽걸이설치', '리퍼상품', '아이티스토리', 'TV>OLED TV', '', '', 'TV·영상가전>TV>초대형(190cm~)', 'Y', '#4K#50인치#LGTV#LG전자#UHD#스마트TV#엘지4K티비#엘지스마트TV#엘지티비#티비', '1199000', '1199000', '0', '', '', '1199000')
# ('0021449187', '24년형 신제품 144Hz AI 퀀텀 플러스 이스트라 75 QLED 구글 스마트TV (이동형타입A/기사방문)', '정상상품', '이스트라', 'TV>QLEDTV', '크기,종류,해상도,응답속도,기본 주사율,엔진,스마트기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과,지원단자,소비전력,VESA간격,색상,HDMI 포트수,USB 포트수,두께,무게,패널 종류,TV 설치 유형,최대 주사율', '75인치(190cm),LED,UHD(4K),6m/s,60Hz,MT9617,구글플레이,USB재생,2등급,2024년,평면형,10~20W 미만,돌비애트모스,HDMI,225W,400*200mm,블랙 계열,3포트,2포트,6cm이상~,25.5,VA패널(CSOT),스탠드형+벽걸이형,144Hz', 'TV·영상가전>TV>초대형(190cm~)', 'Y', '#AU753QLED_5', '5150000', '5150000', '0', '', '', '5150000')
# ('0029569655', '[최상급 / 부곡점] 프로젝터매니아 미니 빔프로젝터 PJM300 (J)PJM300', '진열상품', '프로젝터매니아', 'A/V 기타>프로젝터', '', '', 'TV·영상가전>영상가전>빔프로젝터', 'Y', '#빔프로젝터#빔#빔프로#영상#전시상품', '171264', '93700', '0', '', '', '93700')
# ('0030112073', '[최상급] 미니 빔프로젝터  PJM300', '진열상품', '프로젝터매니아', 'A/V 기타>프로젝터', '', '', 'TV·영상가전>영상가전>빔프로젝터', 'Y', '#빔프로젝터#빔#빔프로#영상#전시상품', '171264', '93700', '0', '', '', '93700')
# ('0037557726', '삼성 건조기 9kg 화이트 DV90TA040TE', '정상상품', '삼성전자', '세탁기>건조기', '건조 용량,건조방식,주요기능,e효율등급,색상,출시년도', '9kg,히트펌프식,구김방지,2등급,화이트 계열,2021년', '세탁기·건조기·의류관리기>건조기·탈수기>건조기', 'Y', '#9kg건조기#건조기#미니건조기#삼성건조기', '932000', '848120', '0', '', '', '848120')
# ('0020514964', '109cm 구글 스마트 TV UA431QLED(자가설치)+[SW180-221R사운드바+우퍼', '정상상품', '더함', 'TV>QLEDTV', '크기,종류,해상도,응답속도,기본 주사율,엔진,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입', '43인치(109cm),QLED,UHD(4K),6ms,60Hz,MT9612,구글플레이,넷플릭스,유튜브,크롬캐스트,구글어시스턴트,웨이브,아마존프라임비디오,Disney+,AppleTV,왓챠플레이,쿠팡플레이,USB재생,블루투스,HDMI CEC,HDMI 2.1 지원,HDMI eARC,크로마서브샘플링(4:4:4),1등급,2023년,평면형', 'TV·영상가전>TV>중소형(~109cm)', 'Y', '#UA431QLED_S180#TV#티비', '552000', '552000', '0', '', '', '552000')
# ('0020623947', '소싱 제로 신발건조기 화이트 S00049_1', '정상상품', '소싱', '여름제품>제습기', '색상', '화이트 계열', '세탁기·건조기·의류관리기>건조기·탈수기>신발건조기', 'Y', '#냄새제거#레포츠#발냄새제거#보드부츠#스키부츠#신발건조#신발냄새#신발냄새제거#신발살균#신발탈취#악취제거', '40000', '25900', '7', '롯데카드', '롯데카드,현대카드,삼성카드', '24090')
# ('0020718055', '소싱 제로 신발건조기 모음 [블루/화이트]', '정상상품', '소싱', '여름제품>제습기', '', '', '세탁기·건조기·의류관리기>건조기·탈수기>신발건조기', 'Y', '#S00049_2#S00049_1#소싱#신발건조기#제습기#신발건조#냄새제거', '40000', '25900', '7', '롯데카드', '롯데카드,현대카드,삼성카드', '24090')
# ('0021476264', '138cm UHD TV KU55UD7000FXKR 스탠드형', '정상상품', '삼성전자', 'TV>UHD TV', '크기,종류,해상도,기본 주사율,엔진,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과,음향효과,지원단자,지원단자,소비전력,VESA간격', '55인치(138cm),LED,UHD,60Hz,크리스탈프로세서,넷플릭스,유튜브,빅스비,USB재생,블루투스,Q심포니,게임모드,HDMI 2.0 지원,HDMI ARC,HDMI CEC,HDMI eARC,1등급,2024년,평면형,20W,AI사운드최적화,OTS Lite,HDMI,LAN,125W,200*200mm', 'TV·영상가전>TV>중형(~139cm)|전문가 화상상담>대형가전>TV', 'Y', '#55인치#삼성TV#TV#55인치TV#UHDTV#UHD#4K업스케일링#TV추천#스마트TV#가성비TV#게이밍TV#게임용TV#슬림TV#베스트TV#인기많은TV#최다판매TV#홈시네마#1등급TV#TV할인#넷플릭스TV#60HzTV#무빙사운드#영화TV', '740000', '740000', '10', '롯데카드', '롯데카드,현대카드,삼성카드', '666000')
# ('0021476332', '138cm UHD TV KU55UD7000FXKR (설치유형 선택가능)', '정상상품', '삼성전자', 'TV>UHD TV', '크기,종류,해상도,기본 주사율,스마트기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과,지원단자,소비전력,VESA간격,색상,HDMI 포트수,USB 포트수,무게,패널 종류,TV 설치 유형', '55인치(138cm),LED,4K UHD (2160p),60Hz,넷플릭스,USB재생,1등급,2023년,평면형,20W,OTS Lite,LAN,250W,400*400mm,블랙,3개,1개,30.4kg,VA패널,스탠드형+벽걸이형', 'TV·영상가전>TV>중형(~139cm)', 'Y', '#55인치#삼성TV#TV#55인치TV#UHDTV#UHD#4K업스케일링#TV추천#스마트TV#가성비TV#게이밍TV#게임용TV#슬림TV#베스트TV#인기많은TV#최다판매TV#홈시네마#1등급TV#TV할인#넷플릭스TV#60HzTV#무빙사운드#영화TV', '740000', '740000', '10', '롯데카드', '롯데카드,현대카드,삼성카드', '666000')
# ('0039005449', '[최상급 / 사하점] 애니빔 안드로이드 빔프로젝터 (J)FAD450', '진열상품', '애니게이트', 'A/V 기타>프로젝터', '', '', 'TV·영상가전>영상가전>빔프로젝터', 'Y', '#전시상품', '320000', '270600', '0', '', '', '270600')
# ('0042747266', 'LG   139cm(55인치) UHD 4K 스마트 TV 55UT8000 미사용리퍼 지방벽걸이설치', '리퍼상품', '아이티스토리', 'TV>UHD TV', '', '', 'TV·영상가전>TV>중형(~139cm)', 'Y', '#4K#LGTV#LG전자#UHD#스마트TV#엘지스마트TV#엘지티비#티비', '829000', '829000', '0', '', '', '829000')
# ('0020478740', 'LG 139cm FHD  디지털 사이니지  LED TV 55SVH7F  [설치유형 선택가능]', '정상상품', '아이티스토리', 'TV>LED TV', '', '', 'TV·영상가전>TV>중형(~139cm)', 'Y', '', '3490000', '3490000', '0', '', '', '3490000')
# ('0020935220', '214cm Neo QLED TV KQ85QNC83AFXKR 스탠드형', '정상상품', '삼성전자', 'TV>네오QLEDTV', '크기,종류,해상도,엔진,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,출시년도,화면 타입,스피커 출력,음향효과,음향효과,지원단자,지원단자,지원단자', '85인치(214cm),QLED,UHD(4K),뉴럴퀀텀프로세서4K,넷플릭스,유튜브,웨이브,알렉사,빅스비,아마존프라임비디오,Disney+,AppleTV,왓챠플레이,쿠팡플레이,Q심포니,게임모드,HDMI CEC,HDMI eARC,2023년,평면형,40W,OTS Lite,돌비애트모스,HDMI,LAN,Optical', 'TV·영상가전>TV>초대형(190cm~)', 'Y', '#KQ85QNC83AFXKR_SS', '8100900', '8100900', '5', '롯데카드', '롯데카드,현대카드,네이버페이,삼성카드,신한카드,KB국민카드', '7900900')
# ('0020984770', '214cm Neo QLED TV KQ85QNC83AFXKR [설치유형 선택가능]', '정상상품', '삼성전자', 'TV>네오QLEDTV', '', '', 'TV·영상가전>TV>초대형(190cm~)', 'Y', '', '8100900', '8100900', '5', '롯데카드', '롯데카드,현대카드,네이버페이,삼성카드,신한카드,KB국민카드', '7900900')
# ('0026376565', '삼성전자 25KG 드럼세탁기 WF25B9400KB', '미개봉상품', '삼성전자', '세탁기>드럼 세탁기', '종류,세탁 용량,e효율등급,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,색상,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,출시년도', '드럼,25kg,1등급,세제자동투입,진동감지센서,스마트컨트롤,스마트타이머,통세척,잠금기능,베이지계열,헹굼+탈수,타월,울,표준,블라우스,아웃도어,AI맞춤세탁,면,섬세,쾌속,아기옷,탈수단독,2022년', '세탁기·건조기·의류관리기>드럼세탁기|세탁기·건조기·의류관리기>미개봉상품>세탁기·건조기', 'Y', '#25kg#입체돌풍세탁#이중필터#무세제통세척#4중진동저감#새틴라이트베이지#삼성#세탁기#드럼세탁기#WF25B9400KB#미개봉특가#미개봉특가#미개봉#미개봉상품#미개봉상품', '1860000', '908000', '0', '', '', '908000')
# ('0024378559', '[상급 / 보령점] 위닉스 텀블건조기 19Kg (메탈릭실버) (J)HGXH190-KSK', '진열상품', '위닉스', '세탁기>건조기', 'e효율등급', '1등급', '세탁기·건조기·의류관리기>건조기·탈수기>건조기|전문가 화상상담>대형가전>건조기', 'Y', '#1등급#가전케어십#안심케어#HGXH190-KSK#의류#전시상품', '1340000', '821500', '0', '', '', '821500')
# ('0024920460', '[상급] [키트미포함] 건조기 HGXH190-KSK (19kg, 듀얼 인버터 컴프레서, 국내최대용량, 초대형 바른건조, 메탈릭 그레이)', '진열상품', '위닉스', '세탁기>건조기', '', '', '세탁기·건조기·의류관리기>건조기·탈수기>건조기|세탁기·건조기·의류관리기>전시상품>건조기·탈수기|안심케어>가전 보험>전시가전수리비보험|전문가 화상상담>대형가전>건조기', 'Y', '#1등급#가전케어십#안심케어#HGXH190-KSK#의류#전시상품', '1340000', '821500', '0', '', '', '821500')
# ('0021346937', '10kg 드럼세탁기 WCG760', '정상상품', '밀레', '세탁기>드럼 세탁기', '종류,세탁 용량,e효율등급,색상,출시년도', '드럼,10kg,1등급,화이트 계열,2023년', '세탁기·건조기·의류관리기>드럼세탁기|전문가 화상상담>대형가전>세탁기', 'Y', '#WCG760#드럼세탁기#밀레코리아#밀레#10kg', '2790000', '2790000', '5', '롯데카드', '롯데카드,현대카드,삼성카드', '2650500')
# ('0030506105', '[25년형] CP43G5 109cm 구글5.0 스마트 4K UHD TV 120Hz 프리핫키 지원 (기사방문/벽걸이설치)', '정상상품', '프리즘코리아', 'TV>LED TV', '크기,종류,해상도,응답속도,기본 주사율,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력', '43인치(109cm),LED,UHD(4K),6m/s,120Hz,구글플레이,넷플릭스,유튜브,음성인식,크롬캐스트,구글어시스턴트,웨이브,아마존프라임비디오,Disney+,쿠팡플레이,USB재생,블루투스,게임모드,HDMI ARC,HDMI CEC,HDMI 2.1 지원,HDMI eARC,1등급,2024년,평면형,24W', 'TV·영상가전>TV>중소형(~109cm)', 'Y', '#43인치TV#4KTV#CP43G5#구글5.0#구글TV#벽걸이TV#스마트TV', '369000', '369000', '10', '롯데카드', '롯데카드,현대카드,네이버페이,삼성카드,신한카드,KB국민카드', '332100')
# ('0043838632', '비스포크 그랑데 AI 원바디 Top-Fit 21+20kg WF2120HDEEC (그레이지)', '정상상품', '삼성전자', '세탁기>드럼 세탁기', 'e효율등급', '1등급', '세탁기·건조기·의류관리기>세탁기+건조기', 'Y', '#삼성원바디#삼성전자21kg드럼세탁기#삼성세탁기#그랑데AI#세탁기#드럼세탁기#WF2120HDEEC#건조기#삼성건조기#세탁기건조기#세탁기건조기세트', '2590000', '1949000', '10', '롯데카드', '롯데카드,현대카드,네이버페이,삼성카드,신한카드,KB국민카드', '1799000')
# ('0028955367', '삼성 비스포크 그랑데 AI 원바디 세탁+건조 세트 WF2120HDVVC', '정상상품', '삼성전자', '세탁기>드럼 세탁기', '종류,세탁 용량,e효율등급,스마트기능,스마트기능,스마트기능,색상,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,건조 용량,출시년도', '세탁기+건조기,21kg,1등급,세제자동투입,스마트컨트롤,통세척,블랙 계열,헹굼+탈수,타월,울,표준,AI맞춤세탁,면,섬세,아기옷,탈수단독,20kg,2024년', '세탁기·건조기·의류관리기>세탁기+건조기', 'Y', '#WF2120HDVVC-', '2240000', '1971200', '5', '롯데카드', '롯데카드,네이버페이,삼성카드', '1872640')
# ('0021399874', '189cm Neo QLED TV KQ75QND90AFXKR 벽걸이형', '정상상품', '삼성전자', 'TV>네오QLEDTV', '크기,종류,해상도,기본 주사율,엔진,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과,음향효과,음향효과,지원단자,지원단자,지원단자,소비전력', '75인치(189cm),QLED,UHD(4K),120Hz,NQ4 AI Gen2,넷플릭스,유튜브,구글어시스턴트,빅스비,USB재생,블루투스,Q심포니,게임모드,HDMI CEC,HDMI eARC,3등급,2024년,평면형,60W,OTS+,AI사운드최적화,돌비애트모스,HDMI,LAN,Optical,300W', 'TV·영상가전>TV>대형(~189cm)|전문가 화상상담>대형가전>TV', 'Y', '#75인치TV#삼성TV#TV#QLEDTV', '5690000', '5690000', '7', '롯데카드', '롯데카드,현대카드,네이버페이,삼성카드,신한카드,KB국민카드', '5540000')
# ('0018699546', '139cm 4K UHD 안드로이드 스마트  TV A550ES9 UHD (설치유형 선택가능)', '정상상품', '써밋티비', 'TV>UHD TV', '', '', 'TV·영상가전>TV>중형(~139cm)', 'Y', '#TV#티비', '469000', '469000', '0', '', '', '469000')
# ('0020620073', 'DOG REPELLER( 도그리펠러) 맹견퇴치기', '정상상품', '보안정보통신', 'A/V 기타>TV 안테나', '', '', 'TV·영상가전>TV>TV액세서리', 'N', '#개물림방지#동물행동제어#맹견방어#애완견훈련#유해견퇴치', '98000', '98000', '0', '', '', '98000')
# ('0000571350', '6kg 일반세탁기 LW60P1', '정상상품', '쿠잉', '세탁기>일반세탁기', '종류,종류,세탁 용량,e효율등급,색상,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,출시년도', '일반,소형,6kg,5등급,그레이 계열,급속,표준,불림,수건,아기옷,2017년', '세탁기·건조기·의류관리기>일반세탁기|전문가 화상상담>대형가전>세탁기', 'Y', '#통돌이세탁기#세탁기#일반세탁기#6kg#물가안정', '239000', '239000', '5', '롯데카드', '롯데카드,현대카드,삼성카드', '0')
# ('0020639080', 'LH65BECHLGF 164Cm 비지니스 TV 스탠드형 4K UHD LED', '정상상품', '삼성전자', 'TV>LED TV', '크기,종류,해상도,엔진,스마트기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,지원단자,지원단자,지원단자,지원단자,소비전력,색상,HDMI 포트수,USB 포트수,무게,TV 설치 유형', '65인치(164cm),LED,UHD(4K),크리스탈프로세서,유튜브,USB재생,블루투스4.2,1등급,2023년,평면형,HDMI,RF,LAN,Optical,195W,블랙 계열,3포트,1포트,20.6kg,스탠드형', 'TV·영상가전>TV>대형(~189cm)', 'Y', '#4K#LED#TV#강의#광고#배너#비지니스#회의', '815000', '815000', '7', '롯데카드', '롯데카드,현대카드,네이버페이,삼성카드,신한카드,KB국민카드', '757950')
# ('0020639085', 'LH65BECHLGF 164Cm 비지니스 TV 4K UHD/LED (설치유형 선택가능)', '정상상품', '삼성전자', 'TV>LED TV', '', '', 'TV·영상가전>TV>대형(~189cm)', 'Y', '', '815000', '815000', '7', '롯데카드', '롯데카드,현대카드,네이버페이,삼성카드,신한카드,KB국민카드', '757950')
# ('0040194852', '81cm FHD QLED 화이트 구글 스마트 무빙TV A320ESW QLED 설치', '정상상품', '써밋티비', 'TV>QLEDTV', '크기,종류,해상도,응답속도,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과,지원단자,지원단자,지원단자,지원단자,지원단자,소비전력,VESA간격,색상,HDMI 포트수', '32인치(81cm),QLED,Full-HD,6.5ms,구글플레이,넷플릭스,유튜브,크롬캐스트,구글어시스턴트,USB재생,블루투스,크로마서브샘플링(4:4:4),1등급,2025년,평면형,20W,돌비디지털,컴포지트,HDMI,RF,LAN,Optical,100W미만,100*100mm,화이트 계열,3포트', 'TV·영상가전>TV>중소형(~109cm)', 'Y', '#32인치TV#OTT#QLED#구글TV#넷플릭스.티빙#무빙TV#삼탠바이미#소형TV#스마트TV#안드로이드TV#원룸TV#유튜브#중소기업TV#화이트TV', '349000', '349000', '0', '', '', '349000')
# ('0021484615', '[전국무료설치]165cm TCL QD-Mini LED 4K TV 안드로이드12 구글 TV 65C79B (벽걸이형)', '정상상품', 'TCL', 'TV>네오QLEDTV', '크기,종류,해상도,응답속도,기본 주사율,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과,음향효과,지원단자,지원단자,지원단자', '65인치(165cm),LED,UHD(4K),8.5ms,120Hz,넷플릭스,유튜브,인터넷,음성인식,구글어시스턴트,아마존프라임비디오,쿠팡플레이,USB재생,블루투스5.0,게임모드,HDMI ARC,HDMI eARC,4등급,2024년,평면형,30W,돌비애트모스,DTS-HD,헤드폰단자,HDMI,RF', 'TV·영상가전>TV>대형(~189cm)', 'Y', '#65인치TV#가성비중형TV#가성비TV#프리미엄TV#GoogleTV#게이밍TV#게임TV#MiniLEDTV#초슬림TV#시네마TV#스마트#TV#TV추천#인기TV#신혼TV#신혼TV추천#TCL#TCLTV', '1299000', '1299000', '7', '롯데카드', '롯데카드,현대카드,삼성카드', '1208070')
# ('0021880079', '24년형 신제품 이스트라 144Hz VRR 65 UHD AI 구글TV 스탠드형 설치', '정상상품', '이스트라', 'TV>NLEDTV', '크기,종류,해상도,응답속도,기본 주사율,엔진,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력', '65인치(164cm),LED,UHD(4K),6m/s,120Hz,MT9617,구글플레이,넷플릭스,유튜브,인터넷,음성인식,크롬캐스트,구글어시스턴트,Disney+,블루투스,게임모드,플리커프리,HDMI CEC,HDMI 2.1 지원,HDMI eARC,크로마서브샘플링(4:4:4),USB재생(동영상·사진·음악),2등급,2024년,평면형,24W', 'TV·영상가전>TV>대형(~189cm)', 'Y', '#65인치TV#65인치티비#TV#스마트TV#스마트티비#안드로이드TV#안드로이드티비#중소기업TV#중소기업티비#티비', '1940000', '1940000', '0', '', '', '1940000')
# ('0018330106', '삼성 139cm 4K UHD TV 55TU7000 스마트 티비 리퍼 설치유형 선택가능', '정상상품', 'MIDOTECH', 'TV>UHD TV', '', '', 'TV·영상가전>TV>중형(~139cm)', 'Y', '#TV', '589000', '589000', '0', '', '', '589000')
# ('0021399903', '247cm UHD TV KU98UD9000FXKR 벽걸이형', '정상상품', '삼성전자', 'TV>UHD TV', '크기,종류,해상도,기본 주사율,엔진,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,출시년도,화면 타입,스피커 출력,음향효과,음향효과,지원단자,지원단자,지원단자', '98인치(247cm),LED,UHD,120Hz,크리스탈프로세서,넷플릭스,유튜브,웨이브,아마존프라임비디오,Disney+,AppleTV,쿠팡플레이,USB재생,블루투스,Q심포니,게임모드,HDMI CEC,HDMI eARC,2024년,평면형,20W,AI사운드최적화,OTS Lite,HDMI,LAN,Optical', 'TV·영상가전>TV>초대형(190cm~)|전문가 화상상담>대형가전>TV', 'Y', '#98인치#TV#UHDTV#삼성TV', '5290000', '5290000', '7', '롯데카드', '롯데카드,현대카드,네이버페이,삼성카드,신한카드,KB국민카드', '5140000')
# ('0018691876', '통돌이 세탁기 12kg 저소음 투명도어 화이트 EWF12WG1W(A)', '정상상품', '위니아', '세탁기>일반세탁기', '종류,세탁 용량,스마트기능,e효율등급,색상,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,출시년도,모터 종류', '일반,12kg,통세척,2등급,화이트 계열,울,최근코스,표준,강력,섬세,아기옷,2022년,AC모터', '세탁기·건조기·의류관리기>일반세탁기', 'Y', '#가성비#선물용#세탁기#스타드럼#통돌이#입체물살', '413000', '413000', '0', '', '', '413000')
# ('0020449152', '엔산 APM-02 셋톱박스선반', '정상상품', '엔산마운트', 'A/V 기타>TV 기타', '색상', '블랙 계열', 'TV·영상가전>TV>TV액세서리', 'N', '#TV셋톱박스선반', '17000', '17000', '0', '', '', '17000')
# ('0022027263', '비스포크 그랑데AI 드럼세탁기 WF24CB8850BW 24kg', '정상상품', '삼성전자', '세탁기>드럼 세탁기', '종류,세탁 용량,e효율등급,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,색상,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,출시년도', '드럼,24kg,1등급,코스다운로드,세탁무게감지,진동감지센서,스마트컨트롤,통세척,잠금기능,화이트 계열,헹굼+탈수,타월,울,표준,블라우스,아웃도어,AI맞춤세탁,면,섬세,쾌속,아기옷,탈수단독,2023년', '세탁기·건조기·의류관리기>드럼세탁기', 'Y', '#WF24CB8850BW_S', '1631500', '1452030', '5', '롯데카드', '롯데카드,네이버페이,삼성카드', '1379430')
# ('0041468778', 'LG 190cm(75) 4K UHD 유튜브 넷플릭스 스마트TV 75UT7550 미사용리퍼 지방벽걸이설치', '리퍼상품', '아이티스토리', 'TV>OLED TV', '', '', 'TV·영상가전>TV>초대형(190cm~)', 'Y', '#4K#50인치#LGTV#LG전자#UHD#스마트TV#엘지4K티비#엘지스마트TV#엘지티비#티비', '1249000', '1249000', '0', '', '', '1249000')
# ('0018324735', 'LG 165cm 4K UHD TV 65UP8000 스마트 티비 리퍼 설치유형 선택가능', '정상상품', 'MIDOTECH', 'TV>UHD TV', '', '', 'TV·영상가전>TV>대형(~189cm)', 'Y', '#TV', '919000', '919000', '0', '', '', '919000')
# ('0020615560', '비스포크 에어드레서 의류관리기 DF24CB99001R', '정상상품', '삼성전자', '세탁기>의류관리기', '용량,살균기능,부가기능,부가기능,출시년도', '상의5벌+하의5벌,바이러스,다운로드코스,스마트폰페어링,2023년', '세탁기·건조기·의류관리기>의류관리기>에어드레서', 'Y', '#DF24CB99001R_S', '3355900', '3020310', '5', '롯데카드', '롯데카드,네이버페이,삼성카드', '2869290')
# ('0021469363', '189cm 울트라 HD TV 75UR8300NNA 스탠드형', '정상상품', 'LG전자', 'TV>UHD TV', '크기,종류,해상도,기본 주사율,엔진,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과,음향효과,지원단자,지원단자,지원단자,지원단자,소비전력,VESA간격,색상', '70~79인치,LED,UHD(4K),60Hz,알파5 Gen6,넷플릭스,유튜브,에어플레이2,USB재생,블루투스5.0,게임모드,스포츠알람,HDMI eARC,1등급,2023년,평면형,20W,공간인식사운드,인공지능사운드,HDMI,RF,LAN,Optical,230W,400*400mm,블랙 계열', 'TV·영상가전>TV>대형(~189cm)', 'Y', '#75UR8300NNA_SS', '1575100', '1575100', '5', '롯데카드', '롯데카드,현대카드,네이버페이,삼성카드,신한카드,KB국민카드', '1496340')
# ('0021470531', '189cm 울트라 HD TV 75UR8300NNA (설치유형 선택가능)', '정상상품', 'LG전자', 'TV>UHD TV', '크기,종류,해상도,기본 주사율,엔진,스마트기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과,지원단자,소비전력,VESA간격,색상,HDMI 포트수,USB 포트수,무게,패널 종류,TV 설치 유형', '75인치(189cm),LED,4K UHD (2160p),60Hz,알파5 Gen6,넷플릭스,USB재생,1등급,2023년,평면형,20W,돌비디지털,LAN,230W,400*400mm,블랙,2개,1개,31.4kg,VA패널,스탠드형+벽걸이형', 'TV·영상가전>TV>대형(~189cm)', 'Y', '#75UR8300NNA_SS', '1575100', '1575100', '5', '롯데카드', '롯데카드,현대카드,네이버페이,삼성카드,신한카드,KB국민카드', '1496340')
# ('0024026419', 'LG 165cm OLED 4K UHD TV OLED65G1 스마트 티비 리퍼 지방벽걸이', '정상상품', 'MIDOTECH', 'TV>OLED TV', '크기,종류,해상도,기본 주사율,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과,지원단자,지원단자,소비전력,VESA간격,색상,HDMI 포트수,USB 포트수,무게,TV 설치 유형', '65인치(163cm),OLED,UHD(4K),60Hz,넷플릭스,유튜브,아마존프라임비디오,에어플레이2,Disney+,AppleTV,USB재생,블루투스5.0,5등급,2020년,평면형,60W,돌비애트모스,HDMI,RF,180W,300*300mm,블랙 계열,4포트,3포트,28.9kg,스탠드형+벽걸이형', 'TV·영상가전>TV>대형(~189cm)', 'Y', '#4K#65인치#LG#LGTV#OLEDTV#UHD#리퍼TV#리퍼티비#스마트TV#엘지티비', '1960000', '1960000', '0', '', '', '1960000')
# ('0019919924', '56cm 22인치 FHD LED 중소기업 22FHD TV (설치유형 선택가능)', '정상상품', '플랜티엄', 'TV>LED TV', '', '', 'TV·영상가전>TV>중소형(~109cm)', 'Y', '#TV#티비', '175000', '175000', '0', '', '', '175000')
# ('0037370622', '5년무상AS 이스트라 120Hz AI 맥스 215cm UHD 구글 5.0 스마트TV (이동스탠드A타입-기사)', '정상상품', '이스트라', 'TV>UHD TV', '크기,종류,해상도,응답속도,기본 주사율,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,출시년도,화면 타입,스피커 출력,음향효과,음향효과,음향효과,지원단자', '85인치(215cm),LED,UHD(4K),6m/s,120Hz,구글플레이,넷플릭스,유튜브,크롬캐스트,구글어시스턴트,Disney+,블루투스,게임모드,플리커프리,HDMI CEC,HDMI 2.1 지원,HDMI eARC,크로마서브샘플링(4:4:4),USB재생(동영상·사진·음악),2025년,평면형,30W,돌비디지털Plus,돌비디지털,돌비애트모스,HDMI', 'TV·영상가전>TV>초대형(190cm~)', 'Y', '#AN857UHD05', '1647000', '1647000', '0', '', '', '1531710')
# ('0042695017', '삼성 177cm(70) UHD 4K 스마트 LED TV 70DU7200 미사용리퍼 지방벽걸이설치', '리퍼상품', '아이티스토리', 'TV>UHD TV', '', '', 'TV·영상가전>TV>대형(~189cm)', 'Y', '#70DU7200-4', '969000', '969000', '0', '', '', '969000')
# ('0020607666', '109cm  바이런 무결점 구글OS 스마트TV / HP43G3 (택배출고/스탠드 자가설치)', '정상상품', '프리즘코리아', 'TV>LED TV', '크기,종류,해상도,응답속도,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과,지원단자', '43인치(109cm),LED,UHD(4K),6ms,구글플레이,넷플릭스,유튜브,크롬캐스트,구글어시스턴트,웨이브,아마존프라임비디오,Disney+,AppleTV,왓챠플레이,쿠팡플레이,USB재생,블루투스,HDMI 2.0 지원,HDMI ARC,HDMI CEC,1등급,2023년,평면형,20W,돌비오디오,컴포지트', 'TV·영상가전>TV>중소형(~109cm)', 'Y', '#HP43G3#TV#티비', '279000', '279000', '0', '', '', '279000')
# ('0020627989', '109cm  바이런 무결점 구글OS 스마트TV / HP43G3 설치유형 선택가능', '정상상품', '프리즘코리아', 'TV>LED TV', '', '', 'TV·영상가전>TV>중소형(~109cm)', 'Y', '#TV#티비', '279000', '279000', '0', '', '', '279000')
# ('0020913939', '[스태킹설치포함] 오브제컬렉션 19KG 건조기 RG19VNS', '정상상품', 'LG전자', '세탁기>건조기', '건조 용량,건조방식,주요기능,주요기능,주요기능,주요기능,주요기능,e효율등급,색상,출시년도,모터 종류', '19kg,히트펌프식,콘덴서자동세척,콘덴서케어,타이머,구김방지,스마트폰페어링,1등급,실버 계열,2023년,인버터 DD모터', '세탁기·건조기·의류관리기>건조기·탈수기>건조기|전문가 화상상담>대형가전>건조기', 'Y', '#오브제컬렉션#19KG#건조기#RG19VNS#드럼건조기#19kg건조기#LG#LG건조기#LG드럼건조기', '1440000', '1440000', '7', '롯데카드', '롯데카드,현대카드,삼성카드', '1339200')
# ('0037357661', '5년무상AS 이스트라 120Hz AI 맥스 127cm QLED 구글 5.0 스마트TV (이젤스탠드A타입-기사)', '정상상품', '이스트라', 'TV>UHD TV', '크기,종류,해상도,응답속도,기본 주사율,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과,음향효과', '50인치(127cm),QLED,UHD(4K),6m/s,120Hz,구글플레이,넷플릭스,유튜브,크롬캐스트,구글어시스턴트,Disney+,블루투스,게임모드,플리커프리,HDMI CEC,HDCP 2.2 지원,HDMI 2.1 지원,HDMI eARC,크로마서브샘플링(4:4:4),USB재생(동영상·사진·음악),1등급,2025년,평면형,24W,돌비디지털Plus,돌비디지털', 'TV·영상가전>TV>중형(~139cm)', 'Y', '#AU507QLED07', '610000', '610000', '0', '', '', '567300')
# ('0021484640', '[전국무료설치]140cm TCL QD-Mini LED 4K TV 안드로이드12 구글 TV 55C79B (벽걸이형)', '정상상품', 'TCL', 'TV>네오QLEDTV', '크기,종류,해상도,응답속도,기본 주사율,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과,음향효과,지원단자,지원단자,지원단자', '55인치(140cm),LED,UHD(4K),6.5m/s,120Hz,넷플릭스,유튜브,인터넷,음성인식,구글어시스턴트,아마존프라임비디오,쿠팡플레이,USB재생,블루투스5.0,게임모드,HDMI ARC,HDMI eARC,4등급,2024년,평면형,30W,돌비애트모스,DTS-HD,헤드폰단자,HDMI,RF', 'TV·영상가전>TV>대형(~189cm)', 'Y', '#55인치TV#가성비중형TV#가성비TV#프리미엄TV#GoogleTV#게이밍TV#게임TV#MiniLEDTV#초슬림TV#시네마TV#스마트#TV#TV추천#인기TV#신혼TV#신혼TV추천#TCL#TCLTV', '949000', '949000', '7', '롯데카드', '롯데카드,현대카드,삼성카드', '882570')
# ('0024859502', '[중급 / 논현신도시점] 위닉스 텀블건조기 17Kg (메탈릭실버) (J)HGXH170-KSK', '진열상품', '위닉스', '세탁기>건조기', 'e효율등급', '1등급', '세탁기·건조기·의류관리기>건조기·탈수기>건조기|전문가 화상상담>대형가전>건조기', 'Y', '#1등급#가전케어십#안심케어#위닉스#HGXH170-KSK#건조기#위닉스건조기#텀블건조기#대형건조기#17KG#의류건조기#전시상품', '1290000', '711200', '0', '', '', '711200')
# ('0032903118', '[상급 / 송탄점] (진열)LG 25KG 트롬/블랙스테인리스/트루스팀 (J)FX25KSR.AKOR', '진열상품', 'LG전자', '세탁기>드럼 세탁기', 'e효율등급', '1등급', '세탁기·건조기·의류관리기>드럼세탁기|전문가 화상상담>대형가전>세탁기', 'Y', '#FX25KSR#LG드럼세탁기#드럼세탁기#세탁기#LG세탁기#25kg#전시상품', '2000000', '1458000', '0', '', '', '1458000')
# ('0040299572', '[5년무상AS]플럭스 191cm(75인치) Mini-LED UHD 4K TV (스탠드형)', '정상상품', 'PLUX', 'TV>네오QLEDTV', '크기,종류,해상도,기본 주사율,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과,음향효과,지원단자,지원단자,지원단자,소비전력', '75인치(191cm),QLED,UHD(4K),144Hz,구글플레이,넷플릭스,유튜브,크롬캐스트,구글어시스턴트,아마존프라임비디오,USB재생,블루투스,HDMI 2.0 지원,HDMI CEC,HDMI 2.1 지원,HDMI eARC,4등급,2025년,평면형,30W,돌비오디오,돌비애트모스,HDMI,LAN,Optical,360W', 'TV·영상가전>TV>초대형(190cm~)|PLUX 전문관>TV|전문가 화상상담>대형가전>TV|하이메이드 전문관>TV', 'Y', '#플럭스#PLUX#플럭스TV#75형#75인치#고화질#대형화면#대형TV#Mini-LED#QLED#OLED#PLUXTV', '1490000', '1490000', '0', '', '', '1490000')
# ('0040299573', '[5년무상AS]플럭스 191cm(75인치) Mini-LED UHD 4K TV (설치유형 선택가능)', '정상상품', 'PLUX', 'TV>네오QLEDTV', '', '', 'TV·영상가전>TV>초대형(190cm~)|PLUX 전문관>TV|전문가 화상상담>대형가전>TV|하이메이드 전문관>TV', 'Y', '', '1490000', '1490000', '0', '', '', '1490000')
# ('0002584401', '스마트빔 족자스크린 가방', '정상상품', '프로젝터매니아', 'A/V 기타>프로젝터', '', '', 'TV·영상가전>영상가전>빔프로젝터', 'Y', '#프로젝터#빔프로젝터#빔프로젝트#미니빔#미니빔프로젝터#미니빔프로젝트#미니프로젝터#스마트빔#스마트빔레이저#족자스크린#스크린#스크린가방', '17400', '17400', '0', '', '', '17400')
# ('0017496930', '드럼 세탁기 WF21T6000KW  (21kg, 화이트)', '정상상품', '삼성전자', '세탁기>드럼 세탁기', '종류,세탁 용량,e효율등급,스마트기능,스마트기능,스마트기능,색상,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,출시년도', '드럼,21kg,1등급,스마트컨트롤,스마트체크,통세척,화이트 계열,헹굼+탈수,클라우드,초절약,울,표준,삶음,쾌속,아기옷,란제리,2020년', '세탁기·건조기·의류관리기>드럼세탁기|전문가 화상상담>대형가전>세탁기', 'Y', '#WF21T6000KW#삼성#세탁기#삼성세탁기#삼성드럼세탁기#드럼세탁기#그랑데', '789000', '789000', '10', '롯데카드', '롯데카드,현대카드,삼성카드', '710100')
# ('0021463653', '[택배배송,별도설치X] 스피드랙 세탁기선반 (W800xD600xH1500) 2.5단 (화이트)', '정상상품', '스피드랙', '백색/생활보조>세탁기보조', '', '', '전문가 화상상담>대형가전>세탁기', 'Y', '#세탁기선반#스피드랙.화이트#선반#하이마트선반#수납용품', '50000', '50000', '7', '롯데카드', '롯데카드,현대카드,삼성카드', '46500')
# ('0024036423', 'LG 165cm OLED 4K UHD TV OLED65C1 스마트 티비 리퍼 수도권스탠드', '정상상품', 'MIDOTECH', 'TV>OLED TV', '크기,종류,해상도,기본 주사율,엔진,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,출시년도,화면 타입,스피커 출력,지원단자,지원단자,소비전력,VESA간격,HDMI 포트수,USB 포트수,무게', '65인치(165cm),OLED,UHD(4K),120Hz,알파9 Gen4,넷플릭스,유튜브,웨이브,아마존프라임비디오,에어플레이2,왓챠플레이,USB재생,블루투스5.0,2020년,평면형,40W,HDMI,RF,130W,300*200mm,4포트,3포트,24kg', 'TV·영상가전>TV>대형(~189cm)', 'Y', '#4K#65인치#LG#LGTV#OLEDTV#UHD#리퍼TV#리퍼티비#스마트TV#엘지티비', '1800000', '1800000', '0', '', '', '1800000')
# ('0042747201', '삼성 139cm(55) UHD 4K 스마트 LED TV 55CU7000 미사용리퍼 지방스탠드설치', '리퍼상품', '아이티스토리', 'TV>UHD TV', '', '', 'TV·영상가전>TV>중형(~139cm)', 'Y', '#55CU7000-3', '609000', '609000', '0', '', '', '609000')
# ('0020374165', '삼성 190cm 8K QLED 스마트 TV 75Q800 리퍼티비 방문수령', '리퍼상품', 'MIDOTECH', 'TV>QLEDTV', '크기,종류,해상도,기본 주사율,엔진,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,출시년도,화면 타입,스피커 출력,지원단자,지원단자,지원단자,VESA간격,HDMI 포트수,USB 포트수,무게', '75인치(190cm),QLED,UHD(8K),60Hz,퀀텀프로세서,넷플릭스,유튜브,구글어시스턴트,알렉사,아마존프라임비디오,에어플레이2,Disney+,AppleTV,USB재생,HDMI 2.0 지원,2021년,평면형,70W,컴포넌트,HDMI,LAN,400*400mm,4포트,2포트,34.3kg', 'TV·영상가전>TV>초대형(190cm~)', 'Y', '#75인치#8K#UHD#리퍼TV#삼성#삼성TV#스마트TV', '2890000', '2890000', '0', '', '', '2890000')
# ('0020620069', '버그헌터 프로파인더 정밀 탐지기세트', '정상상품', '보안정보통신', 'A/V 기타>TV 안테나', '', '', 'TV·영상가전>TV>TV액세서리', 'N', '#도청탐지#몰래카메라탐지#위치추적기탐지#전파탐지기#주파수탐지기', '2170000', '2170000', '0', '', '', '2170000')
# ('0022064817', 'LG 218cm 4K UHD TV 스마트 티비 86UQ7070 리퍼 수도권벽걸이', '정상상품', 'MIDOTECH', 'TV>UHD TV', '크기,종류,해상도,엔진,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,출시년도,화면 타입,스피커 출력,지원단자,지원단자,지원단자,색상,HDMI 포트수,USB 포트수,패널 종류,TV 설치 유형', '86인치(218cm),LED,UHD(4K),알파5 Gen5,넷플릭스,유튜브,인터넷,웨이브,에어플레이2,왓챠플레이,USB재생,블루투스5.0,게임모드,스포츠알람,2022년,평면형,20W,HDMI,LAN,Optical,블랙 계열,2포트,1포트,IPS패널,스탠드형+벽걸이형', 'TV·영상가전>TV>초대형(190cm~)', 'Y', '#4K#86인치#LG#LGTV#UHD#리퍼TV#리퍼티비#스마트TV#엘지티비', '1869000', '1869000', '0', '', '', '1869000')
# ('0017121452', '165cm UHD TV UX65G (설치유형, 전용 액세서리 추가 선택)', '정상상품', '넥스', 'TV>UHD TV', '', '', 'TV·영상가전>TV>대형(~189cm)', 'Y', '', '519000', '519000', '0', '', '', '519000')
# ('0019337159', '165cm UHD TV UX65K (설치유형, 전용 액세서리 추가 선택)', '정상상품', '넥스', 'TV>UHD TV', '', '', 'TV·영상가전>TV>대형(~189cm)', 'Y', '#65인치#4KUHD#TV#티비', '519000', '519000', '0', '', '', '519000')
# ('0021449475', '[5년연장 A/S보증]아쿠아 10.5kg 드럼세탁기 AWM11DMW', '정상상품', '하이얼', '세탁기>드럼 세탁기', '종류,세탁 용량,e효율등급,스마트기능,스마트기능,스마트기능,색상,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,출시년도', '드럼,10.5kg,2등급,스마트타이머,통세척,잠금기능,화이트 계열,찌든때,컬러케어,헹굼+탈수,울,합성섬유,면,섬세,아기옷,실크,에코,2024년', '세탁기·건조기·의류관리기>드럼세탁기|전문가 화상상담>대형가전>세탁기', 'Y', '#세탁기#드럼세탁기#삼성전자#하이얼아쿠아#AWM11DMW#하이얼#하이얼10kg세탁기', '539000', '539000', '5', '롯데카드', '롯데카드,현대카드,삼성카드', '512050')
# ('0022064151', 'LG 190cm 4K UHD 스마트 TV 75UQ7070 리퍼 티비 수도권스탠드', '정상상품', 'MIDOTECH', 'TV>UHD TV', '크기,종류,해상도,엔진,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,출시년도,화면 타입,스피커 출력,지원단자,지원단자,지원단자,색상,HDMI 포트수,USB 포트수,두께,무게,TV 설치 유형', '75인치(190cm),LED,UHD(4K),알파5 Gen5,넷플릭스,유튜브,인터넷,웨이브,에어플레이2,왓챠플레이,USB재생,블루투스5.0,게임모드,스포츠알람,2022년,평면형,20W,HDMI,LAN,Optical,블랙 계열,2포트,1포트,6.09cm,31.3kg,스탠드형+벽걸이형', 'TV·영상가전>TV>초대형(190cm~)', 'Y', '#4K#75인치#LG#LGTV#UHD#리퍼TV#리퍼티비#스마트TV#엘지티비', '1240000', '1240000', '0', '', '', '1240000')
# ('0005857759', '109cm UHD TV UHD43S (스탠드형 자가설치)', '정상상품', '유맥스', 'TV>UHD TV', '크기,종류,해상도,응답속도,기본 주사율,엔진,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,지원단자,지원단자,지원단자,지원단자,지원단자,소비전력,VESA간격,색상,HDMI 포트수', '43인치(109cm),LED,UHD(4K),9.5m/s,60Hz,MSD 3683칩셋,USB재생,HDMI 2.0 지원,HDMI ARC,HDMI CEC,HDCP 2.2 지원,크로마서브샘플링(4:4:4),USB재생(동영상·사진·음악),3등급,2023년,평면형,20W,컴포넌트,컴포지트,HDMI,RF,Optical,73.1W,200*200mm,블랙 계열,3포트', 'TV·영상가전>TV>중소형(~109cm)', 'Y', '#티비#43인치#TV', '246240', '229000', '0', '', '', '229000')
# ('0009189590', '109cm UHD TV UHD43S (설치유형, 전용 액세서리 선택구매 가능)', '정상상품', '유맥스', 'TV>UHD TV', '', '', 'TV·영상가전>TV>중소형(~109cm)', 'Y', '#티비#43인치#TV', '246240', '229000', '0', '', '', '229000')
# ('0018877898', '190cm 안드로이드 스마트 UHD TV A-DR750 google TV (설치유형 선택가능)', '정상상품', '드림티비', 'TV>UHD TV', '', '', 'TV·영상가전>TV>초대형(190cm~)', 'Y', '#티비#tv', '1092000', '1092000', '0', '', '', '1092000')
# ('0018934648', '제우스 A1000N FHD 가정용 4K 단초점 넷플릭스 미니빔 스마트빔프로젝터', '정상상품', '제우스', 'A/V 기타>프로젝터', '방식,해상도,스마트 기능,스마트 기능,밝기(안시),단자,단자,부가기능,부가기능', 'DLP,FHD급,유튜브,넷플릭스,1000안시,HDMI,USB,블루투스,WiFI', 'TV·영상가전>영상가전>빔프로젝터', 'Y', '#가정용비프로젝터#미니빔프로젝터#빔프로젝터#빔프로젝터추천#빔프로젝트#빔프로젝트추천#제우스빔#캠핑빔', '679000', '679000', '0', '', '', '679000')
# ('0014307556', '[지역한정] 그랑데 AI 드럼 세탁기 WF21T6500KW (21kg, 세제자동투입, AI맞춤세탁, 버블워시, 화이트)', '정상상품', '삼성전자', '세탁기>드럼 세탁기', '종류,세탁 용량,e효율등급,스마트기능,스마트기능,스마트기능,색상,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,출시년도', '드럼,21kg,1등급,세제자동투입,스마트컨트롤,통세척,화이트 계열,헹굼+탈수,초절약,타월,울,표준,청정,블라우스,검은면의류,아웃도어,흐린날,AI맞춤세탁,면,강력,삶음,쾌속,아기옷,란제리,탈수단독,2020년', '세탁기·건조기·의류관리기>드럼세탁기|전문가 화상상담>대형가전>세탁기', 'Y', '#그랑데#세탁기#AI#드럼세탁기#무세제통세척#ai맞춤세탁#삶음세탁#WW12T504DTW#삼성#화이트#21kg#삼성전자21KG드럼세탁기', '889000', '889000', '5', '롯데카드', '롯데카드,현대카드,삼성카드', '844550')
# ('0044272463', '[최상급 / 영종점] LG 뉴디자인 21KG 드럼세탁기 블랙 (J)FG21KN.AKOR2', '진열상품', 'LG전자', '세탁기>드럼 세탁기', 'e효율등급', '1등급', '세탁기·건조기·의류관리기>드럼세탁기', 'Y', '#FG21KN#세탁기#드럼세탁기#LG#LG세탁기#트롬#전시상품', '1600000', '1187000', '0', '', '', '1187000')
# ('0044366865', '215cm QLED 구글 UHD 스마트TV A850ES QLED 이동식스탠드 설치', '정상상품', '써밋티비', 'TV>QLEDTV', '크기,종류,해상도,응답속도,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,e효율등급,출시년도,화면 타입,지원단자,지원단자,지원단자,지원단자,지원단자,소비전력,VESA간격,TV 설치 유형', '80인치 이상,QLED,UHD(4K),9~13m/s 미만,구글플레이,넷플릭스,유튜브,크롬캐스트,구글어시스턴트,1등급,2025년,평면형,컴포지트,HDMI,RF,LAN,Optical,100~200W미만,200*200mm,스탠드형+벽걸이형', 'TV·영상가전>TV>초대형(190cm~)', 'Y', '#85인치TV#OTT#QLED#구글TV#넷플릭스.티빙#대형TV#스마트TV#안드로이드TV#유튜브#중소기업TV', '1790000', '1790000', '0', '', '', '1790000')
# ('0023699248', '139cm 5년무상AS 초고화질 이스트라 144Hz AI 55 QD-Mini LED 퀀텀사운드 구글TV (자가설치/직배송)', '정상상품', '이스트라', 'TV>LED TV', '크기,종류,해상도,응답속도,엔진,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과', '55인치(139cm),LED,UHD(4K),6ms,MT9617,구글플레이,넷플릭스,유튜브,크롬캐스트,구글어시스턴트,웨이브,Disney+,AppleTV,쿠팡플레이,블루투스,HDMI CEC,HDCP 2.2 지원,HDMI 2.1 지원,HDMI eARC,크로마서브샘플링(4:4:4),USB재생(동영상·사진·음악),3등급,2024년,평면형,50W,돌비디지털', 'TV·영상가전>TV>중형(~139cm)', 'Y', '#UC553MLED01', '720000', '720000', '0', '', '', '669600')
# ('0023699965', '139cm 5년무상AS 초고화질 이스트라 144Hz AI 55 QD-Mini LED 퀀텀사운드 구글TV (설치유형 선택가능)', '정상상품', '이스트라', 'TV>LED TV', '', '', 'TV·영상가전>TV>중형(~139cm)', 'Y', '', '720000', '720000', '0', '', '', '669600')
# ...
# ('0020623445', '카멜 25cm PF1030BR IPS패널 광시야각 매대형 거치대패키지 디지털액자', '정상상품', '카멜', '모니터>LED 일반', '', '', 'TV·영상가전>영상가전>디지털액자', 'Y', '#10인치모니터#광고용모니터#디지털액자#모니터#모니터추천#액자#행사용모니터', '131000', '131000', '10', '롯데카드', '롯데카드,삼성카드', '117900')
# ('0018259558', 'LG 109cm 43UP7000PUA UHD 4K 스마트 리퍼 TV 설치유형 선택가능', '정상상품', 'MIDOTECH', 'TV>UHD TV', '', '', 'TV·영상가전>TV>중소형(~109cm)', 'Y', '#TV', '459000', '459000', '0', '', '', '459000')
# ('0021880065', '24년형 신제품 이스트라 144Hz VRR 65 UHD AI 구글TV 이동형스탠드(', '정상상품', '이스트라', 'TV>NLEDTV', '크기,종류,해상도,응답속도,기본 주사율,엔진,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력', '65인치(164cm),LED,UHD(4K),6m/s,120Hz,MT9617,구글플레이,넷플릭스,유튜브,인터넷,음성인식,크롬캐스트,구글어시스턴트,Disney+,블루투스,게임모드,플리커프리,HDMI CEC,HDMI 2.1 지원,HDMI eARC,크로마서브샘플링(4:4:4),USB재생(동영상·사진·음악),2등급,2024년,평면형,24W', 'TV·영상가전>TV>대형(~189cm)', 'Y', '#65인치TV#65인치티비#TV#스마트TV#스마트티비#안드로이드TV#안드로이드티비#중소기업TV#중소기업티비#티비', '2130000', '2130000', '0', '', '', '2130000')
# ('0018138856', 'LG 165cm 4K UHD TV 스마트 티비 65UP7670 리퍼 (설치유형 선택가능)', '정상상품', 'MIDOTECH', 'TV>UHD TV', '', '', 'TV·영상가전>TV>대형(~189cm)', 'Y', '#TV', '899000', '899000', '0', '', '', '899000')
# ('0021399948', '163cm OLED TV KQ65SD95AFXKR 스탠드형', '정상상품', '삼성전자', 'TV>OLED TV', '크기,종류,해상도,기본 주사율,엔진,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과,음향효과,음향효과,지원단자,지원단자,지원단자', '65인치(163cm),OLED,UHD(4K),120Hz,NQ4 AI Gen2,넷플릭스,유튜브,음성인식,구글어시스턴트,빅스비,USB재생,블루투스,Q심포니,게임모드,HDMI CEC,HDMI eARC,4등급,2024년,평면형,70W,OTS+,AI사운드최적화,돌비애트모스,HDMI,LAN,Optical', 'TV·영상가전>TV>대형(~189cm)|전문가 화상상담>대형가전>TV', 'Y', '#TV#OLEDTV#삼성TV#65인치TV', '3850000', '3850000', '7', '롯데카드', '롯데카드,현대카드,네이버페이,삼성카드,신한카드,KB국민카드', '3700000')
# ('0021403552', '163cm OLED TV KQ65SD95AFXKR (설치유형 선택가능)', '정상상품', '삼성전자', 'TV>OLED TV', '크기,종류,해상도,기본 주사율,엔진,스마트기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과,지원단자,소비전력,VESA간격,색상,HDMI 포트수,USB 포트수,무게,TV 설치 유형', '65인치(163cm),OLED,4K UHD (2160p),120Hz,NQ4 AI Gen2,넷플릭스,USB재생,4등급,2024년,평면형,70W,돌비애트모스,LAN,560W,400*300mm,블랙,4개,4개,18.9kg,스탠드형+벽걸이형', 'TV·영상가전>TV>대형(~189cm)', 'Y', '#TV#OLEDTV#삼성TV#65인치TV', '3850000', '3850000', '7', '롯데카드', '롯데카드,현대카드,네이버페이,삼성카드,신한카드,KB국민카드', '3700000')
# ('0021900383', '217cm 울트라 HD TV 86UR8300ENA 벽걸이형', '정상상품', 'LG전자', 'TV>UHD TV', '크기,종류,해상도,기본 주사율,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,출시년도,화면 타입,스피커 출력,음향효과,음향효과,음향효과,지원단자,지원단자,지원단자', '80인치 이상,LED,UHD(4K),120Hz,넷플릭스,유튜브,스마트리모컨,음성인식,아마존프라임비디오,에어플레이2,Disney+,AppleTV,USB재생,블루투스5.0,게임모드,스포츠알람,HDMI eARC,2023년,평면형,20W,공간인식사운드,인공지능사운드,돌비디지털,HDMI,RF,LAN', 'TV·영상가전>TV>초대형(190cm~)', 'Y', '#86UR8300ENA_SM#86인치TV#대형TV#LG86인치#LGTV#LG인기TV#TV#UHD#UHDTV#LED#LEDTV#중형TV#스마트TV#시네마TV#게임TV#게이밍TV#TV추천#인기TV#신혼TV#신혼TV추천#4KTV#4KUHD', '2094500', '2094500', '5', '롯데카드', '롯데카드,현대카드,네이버페이,삼성카드,신한카드,KB국민카드', '1989770')
# ('0037357697', '5년무상AS 이스트라 120Hz AI 맥스 127cm UHD 구글 5.0 스마트TV (벽걸이상하좌우-기사)', '정상상품', '이스트라', 'TV>UHD TV', '크기,종류,해상도,응답속도,기본 주사율,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과,음향효과,지원단자', '50인치(127cm),LED,UHD(4K),6m/s,120Hz,구글플레이,넷플릭스,유튜브,크롬캐스트,구글어시스턴트,Disney+,블루투스,게임모드,플리커프리,HDMI CEC,HDMI 2.1 지원,HDMI eARC,크로마서브샘플링(4:4:4),USB재생(동영상·사진·음악),1등급,2025년,평면형,24W,돌비디지털Plus,돌비디지털,HDMI', 'TV·영상가전>TV>중형(~139cm)', 'Y', '#AN507UHD04', '528000', '528000', '0', '', '', '491040')
# ('0027874640', '삼성 HD TV 80cm 스탠드형 UN32N4010AFXKR(S) [설치X]', '정상상품', '삼성전자', 'TV>LED TV', '크기,종류,해상도,부가기능,e효율등급,화면 타입,스피커 출력,지원단자,지원단자,지원단자,지원단자,소비전력,HDMI 포트수,USB 포트수,무게,TV 설치 유형', '32인치(80cm),LED,HD,USB재생,1등급,평면형,10W,컴포넌트,컴포지트,HDMI,Optical,48W,2포트,1포트,3.8kg,스탠드형', 'TV·영상가전>TV>중소형(~109cm)', 'Y', '#UN32N4010AFXKR(S)-', '315000', '315000', '0', '', '', '315000')
# ('0029942430', 'BESPOKE AI 콤보 허리사랑 수납함 WE702NB (새틴라이트베이지)', '정상상품', '삼성전자', '백색/생활보조>세탁기보조', '', '', '세탁기·건조기·의류관리기>드럼세탁기', 'Y', '#WE702NB#세탁기수납함#세탁기콤보#세탁기#건조기#삼성세탁기#WD25DB8995BB#WD25DB8995BBN', '300000', '300000', '5', '롯데카드', '롯데카드,현대카드,삼성카드', '285000')
# ('0020441685', '삼성 86인치 UHD 4K 스마트 LED TV 86TU9010 설치유형 선택가능', '정상상품', '아이티스토리', 'TV>UHD TV', '', '', 'TV·영상가전>TV>초대형(190cm~)', 'Y', '#TV', '2399000', '2399000', '0', '', '', '2399000')
# ('0026697874', '오브제컬렉션 스타일러 의류관리기 SC5MBR43', '정상상품', 'LG전자', '세탁기>의류관리기', '살균기능,살균기능,살균기능,살균기능,부가기능,색상,출시년도', '침구,바이러스,인형,아기옷,스마트진단,베이지계열,2024년', '세탁기·건조기·의류관리기>의류관리기>스타일러', 'Y', '#SC5MBR43_S', '2538600', '2284740', '5', '롯데카드', '롯데카드,네이버페이,삼성카드', '2170500')
# ('0040921472', '티비아울렛 55인치 4K UHD 슬림베젤 LED TV BR55UHD 고객직접픽업', '정상상품', '티비아울렛', 'TV>UHD TV', '크기,종류,해상도,응답속도,기본 주사율,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,화면 타입,스피커 출력,음향효과,지원단자,지원단자,지원단자,VESA간격,HDMI 포트수,USB 포트수,패널 종류,TV 설치 유형', '55인치(139cm),LED,UHD,5~9m/s 미만,60Hz,구글플레이,넷플릭스,유튜브,크롬캐스트,구글어시스턴트,아마존프라임비디오,Disney+,USB재생,블루투스,평면형,20W,돌비오디오,컴포지트,HDMI,Optical,400*300mm,3포트,2포트,VA패널,스탠드형+벽걸이형', 'TV·영상가전>TV>중형(~139cm)', 'Y', '#BR55UHD', '329000', '329000', '0', '', '', '329000')
# ('0040921818', '티비아울렛 55인치 4K UHD 슬림베젤 LED TV BR55UHD (설치유형 선택가능)', '정상상품', '티비아울렛', 'TV>UHD TV', '', '', 'TV·영상가전>TV>중형(~139cm)', 'Y', '', '329000', '329000', '0', '', '', '329000')
# ('0021880057', '139cm 24년형 신제품 이스트라 120Hz VRR 55 UHD AI 구글TV 스탠드형 ', '정상상품', '이스트라', 'TV>UHD TV', '크기,종류,해상도,응답속도,기본 주사율,엔진,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력', '55인치(139cm),LED,UHD(4K),6m/s,120Hz,MT9617,구글플레이,넷플릭스,유튜브,인터넷,음성인식,크롬캐스트,구글어시스턴트,Disney+,블루투스,게임모드,플리커프리,HDMI CEC,HDMI 2.1 지원,HDMI eARC,크로마서브샘플링(4:4:4),USB재생(동영상·사진·음악),1등급,2024년,평면형,24W', 'TV·영상가전>TV>중형(~139cm)', 'Y', '#VRR55UHD02', '2020000', '2020000', '0', '', '', '2020000')
# ('0018102067', '[스태킹키트미포함] 그랑데 AI 건조기 9kg DV90T5740SE', '정상상품', '삼성전자', '세탁기>건조기', '건조 용량,건조방식,주요기능,주요기능,주요기능,주요기능,e효율등급,색상,출시년도', '9kg,히트펌프식,AI건조,에어살균,타이머,구김방지,1등급,그레이 계열,2020년', '세탁기·건조기·의류관리기>건조기·탈수기>건조기|전문가 화상상담>대형가전>건조기', 'Y', '#삼성전자9kg건조기#DV90T5740SE#9kg', '970000', '970000', '7', '롯데카드', '롯데카드,현대카드,삼성카드', '902100')
# ('0041467585', '삼성 QLED 4K TV 189cm 벽걸이형 KQ75QC75AFXKR(W)', '정상상품', '삼성전자', 'TV>QLEDTV', '크기,종류,해상도,기본 주사율,엔진,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과,음향효과,지원단자,지원단자', '75인치(189cm),QLED,UHD(4K),120Hz,뉴럴퀀텀프로세서4K,넷플릭스,유튜브,인터넷,음성인식,구글어시스턴트,빅스비,USB재생,블루투스,Q심포니,게임모드,HDMI ARC,HDMI CEC,HDMI eARC,3등급,2023년,평면형,20W,AI사운드최적화+,OTS Lite,HDMI,LAN', 'TV·영상가전>TV>대형(~189cm)', 'Y', '#189cm#4K#75인치티비#KQ75QC75AFXKR(W)#QC75#QLED#TV#벽걸이형#삼성#삼성75인치티비', '2270000', '2270000', '0', '', '', '2270000')
# ('0027527956', '오브제컬렉션 25kg 드럼세탁기 FX25EAR', '정상상품', 'LG전자', '세탁기>드럼 세탁기', '종류,세탁 용량,e효율등급,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,색상,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,출시년도', '드럼,25kg,1등급,코스다운로드,세탁무게감지,에너지모니터링,스마트케어,원격제어,통세척,베이지계열,찌든때,조용조용,컬러케어,헹굼+탈수,찬물세탁,울,표준,섬세,아기옷,기능성의류,탈수단독,옷감보호,교복,키즈옷,장마철세탁,2024년', '세탁기·건조기·의류관리기>드럼세탁기', 'Y', '#LG#LG전자#세탁기#드럼세탁기#FX25EAR', '2000000', '2000000', '5', '롯데카드', '롯데카드,현대카드,삼성카드', '1900000')
# ('0002584398', '스마트빔 마이크로 HDMI케이블 노트북 연결용', '정상상품', '프로젝터매니아', 'A/V 기타>프로젝터', '', '', 'TV·영상가전>영상가전>빔프로젝터', 'Y', '#프로젝터#빔프로젝트#빔프로젝터#미니빔#미니빔프로젝터#미니빔프로젝트#미니프로젝터#스마트빔#스마트빔레이저#케이블#hdmi케이블#마이크로hdmi케이블', '16500', '16500', '0', '', '', '16500')
# ('0020601535', '81cm QLED 스마트 구글 TV NA321QLED[스탠드 기사설치]', '정상상품', '더함', 'TV>네오QLED8KTV', '크기,종류,해상도,응답속도,기본 주사율,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,지원단자,지원단자,지원단자,지원단자,소비전력,VESA간격', '32인치(81cm),QLED,Full-HD,5m/s,60Hz,구글플레이,넷플릭스,유튜브,크롬캐스트,구글어시스턴트,블루투스,플리커프리,HDMI ARC,HDMI CEC,크로마서브샘플링(4:4:4),USB재생(동영상·사진),1등급,2023년,평면형,24W,HDMI,RF,LAN,Optical,45W,200*200mm', 'TV·영상가전>TV>중소형(~109cm)', 'Y', '#32인치TV#스마트TV#안드로이드TV#중소기업TV#티비', '249000', '249000', '0', '', '', '249000')
# ('0026967938', '[스탠드형]삼성전자 LH85BEDHLGF 215Cm 4K UHD HDR10+ 1등급 비지니스 TV', '정상상품', '삼성전자', 'TV>LED TV', '크기,종류,해상도,기본 주사율,엔진,스마트기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과,지원단자,지원단자,지원단자,소비전력,VESA간격,색상,HDMI 포트수,USB 포트수,두께,무게,TV 설치 유형', '80인치 이상,LED,UHD(4K),60Hz,퀀텀프로세서,유튜브,블루투스,1등급,2024년,평면형,10~20W 미만,OTS Lite,HDMI,RF,LAN,200~300W미만,600*400mm,블랙 계열,3포트,1포트,6cm이상~,30~40kg 미만,스탠드형', 'TV·영상가전>TV>초대형(190cm~)', 'Y', '#4K#85인치#TV#UHD#광고#비지니스#회사#회의', '1570000', '1570000', '7', '롯데카드', '롯데카드,현대카드,네이버페이,삼성카드,신한카드,KB국민카드', '1460100')
# ('0027029933', '삼성전자 LH85BEDHLGF 215Cm 4K UHD HDR10+ 1등급 비지니스 TV (설치유형 선택가능)', '정상상품', '삼성전자', 'TV>LED TV', '', '', 'TV·영상가전>TV>초대형(190cm~)', 'Y', '', '1570000', '1570000', '7', '롯데카드', '롯데카드,현대카드,네이버페이,삼성카드,신한카드,KB국민카드', '1460100')
# ('0045623384', '[5년 보증] 프리즘 109cm 화이트 구글5.0 스마트 4K UHD TV CP43G5W_기사방문(스탠드설치)', '정상상품', '프리즘코리아', 'TV>UHD TV', '크기,종류,해상도,응답속도,기본 주사율,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능', '109cm,LED,UHD(4K),6ms,60Hz,구글플레이,넷플릭스,유튜브,인터넷,스마트리모컨,음성인식,크롬캐스트,구글어시스턴트,웨이브,아마존프라임비디오,에어플레이2,Disney+,AppleTV,왓챠플레이,쿠팡플레이,USB재생,블루투스,게임모드,HDMI CEC,HDMI 2.1 지원,HDMI eARC', 'TV·영상가전>TV>중형(~139cm)', 'Y', '#구글TV#삼탠바이미#스마트TV#중소바이미#중탠바이미#프리즘TV#화이트TV', '459000', '459000', '0', '', '', '459000')
# ('0021900381', '217cm 울트라 HD TV 86UR8300ENA 스탠드형', '정상상품', 'LG전자', 'TV>UHD TV', '크기,종류,해상도,기본 주사율,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,출시년도,화면 타입,스피커 출력,음향효과,음향효과,음향효과,지원단자,지원단자,지원단자', '80인치 이상,LED,UHD(4K),120Hz,넷플릭스,유튜브,스마트리모컨,음성인식,아마존프라임비디오,에어플레이2,Disney+,AppleTV,USB재생,블루투스5.0,게임모드,스포츠알람,HDMI eARC,2023년,평면형,20W,공간인식사운드,인공지능사운드,돌비디지털,HDMI,RF,LAN', 'TV·영상가전>TV>초대형(190cm~)', 'Y', '#86UR8300ENA_SS', '2094500', '2094500', '5', '롯데카드', '롯데카드,현대카드,네이버페이,삼성카드,신한카드,KB국민카드', '1989770')
# ('0021900656', '217cm 울트라 HD TV 86UR8300ENA (설치유형 선택가능)', '정상상품', 'LG전자', 'TV>UHD TV', '', '', 'TV·영상가전>TV>초대형(190cm~)', 'Y', '', '2094500', '2094500', '5', '롯데카드', '롯데카드,현대카드,네이버페이,삼성카드,신한카드,KB국민카드', '1989770')
# ('0027970813', 'LG 트롬 15kg 드럼세탁기 F15SQAP', '정상상품', 'LG전자', '세탁기>드럼 세탁기', '종류,세탁 용량,e효율등급,스마트기능,스마트기능,스마트기능,스마트기능,색상,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,출시년도,모터 종류', '드럼,15kg,1등급,코스다운로드,세탁무게감지,에너지모니터링,원격제어,실버 계열,찌든때,조용조용,컬러케어,헹굼+탈수,찬물세탁,울,표준,아기옷,기능성의류,옷감보호,장마철세탁,탈수전용,2022년,인버터 DD모터', '세탁기·건조기·의류관리기>드럼세탁기', 'Y', '#F15SQAP_H', '835000', '751500', '0', '', '', '751500')
# ('0042747309', 'LG   139cm(55인치) UHD 4K 스마트 TV 55UR8000 미사용리퍼 서울경기스탠드설치', '리퍼상품', '아이티스토리', 'TV>UHD TV', '', '', 'TV·영상가전>TV>중형(~139cm)', 'Y', '#4K#LGTV#LG전자#UHD#스마트TV#엘지스마트TV#엘지티비#티비', '669000', '669000', '0', '', '', '669000')
# ('0015417365', '127cm 4K UHD TV PT500UD (설치유형 선택가능)', '정상상품', '프리즘코리아', 'TV>UHD TV', '', '', 'TV·영상가전>TV>중형(~139cm)', 'Y', '#티비#50인치#TV', '999000', '999000', '0', '', '', '999000')
# ('0034584221', '삼성 비스포크 그랑데 AI 원바디 드럼세탁기+건조기 (25kg+20kg) 블랙캐비어 WF2520HCVVD', '정상상품', '삼성전자', '세탁기>드럼 세탁기', '종류,세탁 용량,e효율등급,스마트기능,스마트기능,스마트기능,색상,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,건조 용량,출시년도', '세탁기+건조기,25kg,1등급,세제자동투입,스마트컨트롤,통세척,블랙 계열,헹굼+탈수,타월,표준,AI맞춤세탁,면,섬세,아기옷,탈수단독,20kg,2024년', '세탁기·건조기·의류관리기>세탁기+건조기', 'Y', '#WF2520HCVVD-', '2571000', '2339610', '5', '롯데카드', '롯데카드,네이버페이,삼성카드', '2222630')
# ('0018074248', '삼성 165cm 4K UHD TV 스마트 티비 65TU8300 리퍼 (설치유형 선택가능)', '정상상품', 'MIDOTECH', 'TV>UHD TV', '', '', 'TV·영상가전>TV>대형(~189cm)', 'Y', '#TV', '939000', '939000', '0', '', '', '939000')
# ('0020304603', '삼성 190cm UHD 4K 스마트 LED TV 75Q60 설치유형 선택가능', '정상상품', '아이티스토리', 'TV>QLEDTV', '', '', 'TV·영상가전>TV>초대형(190cm~)', 'Y', '#75인치#TV', '1308000', '1308000', '0', '', '', '1308000')
# ('0016995139', '217cm QUQU Q8600UHD HDR SMART (설치유형 선택가능)', '정상상품', '경성글로벌코리아', 'TV>UHD TV', '', '', 'TV·영상가전>TV>초대형(190cm~)', 'Y', '#86인치#TV#4KUHD#티비', '1640000', '1640000', '0', '', '', '1640000')
# ('0018943743', '루컴즈 70인치~75인치 전용 TV 벽걸이 브라켓(상하조절형) ', '정상상품', '루컴즈', 'A/V 기타>TV 기타', '색상', '블랙 계열', 'TV·영상가전>TV>TV액세서리', 'N', '#TV브라켓#루컴즈#루컴즈TV#루컴즈브라켓#브라켓', '28000', '28000', '0', '', '', '28000')
# ('0021397846', '189cm Crystal UHD TV KU75UD8000FXKR 벽걸이형', '정상상품', '삼성전자', 'TV>UHD TV', '크기,종류,해상도,기본 주사율,엔진,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과,음향효과,지원단자,지원단자,지원단자,소비전력', '75인치(189cm),LED,UHD(4K),60Hz,크리스탈프로세서,넷플릭스,유튜브,구글어시스턴트,빅스비,USB재생,블루투스,Q심포니,게임모드,HDMI ARC,HDMI CEC,HDMI eARC,1등급,2024년,평면형,20W,AI사운드최적화,OTS Lite,HDMI,LAN,Optical,255W', 'TV·영상가전>TV>대형(~189cm)|전문가 화상상담>대형가전>TV', 'Y', '#TV#UHDTV#삼성TV#75인치', '2040000', '2040000', '7', '롯데카드', '롯데카드,현대카드,삼성카드', '1897200')
# ('0022064704', '삼성 비스포크 그랑데 AI 24kg 세탁기 WF24CB8850BW-', '정상상품', '삼성전자', '세탁기>드럼 세탁기', '종류,세탁 용량,e효율등급,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,색상,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,출시년도', '드럼,23kg~,1등급,코스다운로드,세탁무게감지,진동감지센서,스마트컨트롤,통세척,잠금기능,화이트 계열,헹굼+탈수,타월,울,표준,블라우스,아웃도어,AI맞춤세탁,면,섬세,쾌속,아기옷,탈수단독,2023년', '세탁기·건조기·의류관리기>드럼세탁기', 'Y', '#24kg#AI#WF24CB8850BW#WF24CB8850BW-#그랑데#비스포크#삼성#세탁기', '1278000', '1150200', '0', '', '', '1150200')
# ('0045690765', '[최상급] 163cm LG 올레드 evo TV OLED65C4FNA (벽걸이형)', '진열상품', 'LG전자', 'TV>OLED TV', '', '', 'TV·영상가전>TV>대형(~189cm)', 'Y', '#LGTV#LG올레드evoTV#LG올레드TV#전시상품', '4090000', '2790000', '0', '', '', '2790000')
# ('0020514695', '트롬 드럼세탁기 F19WDWP 19kg', '정상상품', 'LG전자', '세탁기>드럼 세탁기', '종류,세탁 용량,e효율등급,스마트기능,스마트기능,스마트기능,스마트기능,색상,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,세탁코스,출시년도,모터 종류', '드럼,19kg,1등급,코스다운로드,세탁무게감지,에너지모니터링,원격제어,화이트 계열,찌든때,조용조용,컬러케어,헹굼+탈수,찬물세탁,울,표준,아기옷,기능성의류,교복,키즈옷,장마철세탁,탈수전용,2022년,인버터 DD모터', '세탁기·건조기·의류관리기>드럼세탁기', 'Y', '#F19WDWP_S#LG#엘지', '1034500', '920700', '5', '롯데카드', '롯데카드,네이버페이,삼성카드', '874660')
# ('0022208700', '와이드무빙뷰 68.5cm  EKW271FMA11 화이트에디션 삼탠바이미 셋트 ', '정상상품', '와이드뷰', 'TV>LED TV', '크기,종류,해상도,응답속도,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,지원단자,지원단자,소비전력,VESA간격,색상,HDMI 포트수', '27인치(68cm),LED,Full-HD,7m/s,구글플레이,넷플릭스,유튜브,인터넷,스마트리모컨,음성인식,크롬캐스트,쿠팡플레이,USB재생,블루투스,플리커프리,HDMI CEC,1등급,2024년,평면형,10W,헤드폰단자,HDMI,48W,100*100mm,화이트 계열,2포트', 'TV·영상가전>TV>중소형(~109cm)', 'Y', '#27인치모니터#27인치티비#30인치티비#삼탠바이미#스마트27인치#스마트모니터#스마트티비#스탠바이미#이동식티비#중소기업티비', '291000', '291000', '0', '', '', '291000')
# ('0021389920', '[택배배송,별도설치X]스피드랙 세탁기 선반 (W800xD600xH1500) 2.5단 (블랙)', '정상상품', '스피드랙', '백색/생활보조>세탁기보조', '', '', '전문가 화상상담>대형가전>세탁기', 'Y', '#스피드랙#세탁기선반#수납용품', '80000', '80000', '7', '롯데카드', '롯데카드,현대카드,삼성카드', '74400')
# ('0024858714', '[중급 / 양주LF스퀘어점] 위닉스 텀블건조기 17Kg (메탈릭실버) (J)HGXH170-KSK', '진열상품', '위닉스', '세탁기>건조기', 'e효율등급', '1등급', '세탁기·건조기·의류관리기>건조기·탈수기>건조기|전문가 화상상담>대형가전>건조기', 'Y', '#1등급#가전케어십#안심케어#위닉스#HGXH170-KSK#건조기#위닉스건조기#텀블건조기#대형건조기#17KG#의류건조기#전시상품', '1290000', '711200', '0', '', '', '711200')
# ('0016992265', '125.7cm 4K UHD 비즈니스 TV LH50BEAHLGFXKR 스탠드 무료설치', '정상상품', '삼성전자', 'TV>UHD TV', '크기,해상도,엔진,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,음향효과,지원단자,지원단자,지원단자,지원단자,소비전력,색상,HDMI 포트수,USB 포트수,무게,TV 설치 유형', '50인치(125.7cm),UHD(4K),크리스탈프로세서,구글플레이,유튜브,인터넷,USB재생,블루투스,HDMI ARC,HDMI CEC,1등급,2021년,평면형,돌비디지털Plus,HDMI,RF,LAN,Optical,140W,블랙 계열,3포트,1포트,11.4kg,스탠드형', 'TV·영상가전>TV>중형(~139cm)', 'Y', '#LH50BEATHLGFXKR-S#50인치#TV#티비', '559000', '559000', '0', '', '', '559000')
# ('0017522769', '125.7cm 4K UHD 비즈니스 TV LH50BEAHLGFXKR (설치유형 선택가능)', '정상상품', '삼성전자', 'TV>UHD TV', '', '', 'TV·영상가전>TV>중형(~139cm)', 'Y', '#50인치#TV#티비', '559000', '559000', '0', '', '', '559000')
# ('0028954822', '[25년형] CP65G5Q 165cm 구글5.0 스마트 4K QLED TV 120Hz 프리핫키 지원(기사배송／벽걸이설치)', '정상상품', '프리즘코리아', 'TV>LED TV', '크기,종류,해상도,응답속도,기본 주사율,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,스마트기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,부가기능,e효율등급,출시년도,화면 타입,스피커 출력,음향효과,지원단자', '65인치(165cm),QLED,UHD(4K),6m/s,120Hz,구글플레이,넷플릭스,유튜브,음성인식,크롬캐스트,구글어시스턴트,아마존프라임비디오,쿠팡플레이,USB재생,블루투스,게임모드,HDMI ARC,HDMI CEC,HDMI 2.1 지원,HDMI eARC,1등급,2024년,평면형,24W,돌비애트모스,헤드폰단자', 'TV·영상가전>TV>대형(~189cm)', 'Y', '#65인치TV#CP65G5Q#QLED#구글5.0#구글TV#벽걸이TV#스마트TV', '779000', '779000', '10', '롯데카드', '롯데카드,현대카드,네이버페이,삼성카드,신한카드,KB국민카드', '701100')
# ('0044219698', 'LG 트롬 드럼 세탁기 24kg F24WDWP', '정상상품', 'LG전자', '세탁기>드럼 세탁기', 'e효율등급', '1등급', '세탁기·건조기·의류관리기>드럼세탁기', 'Y', '#24kg#F24WDWP#LG#드럼#드럼세세탁기#세탁기#엘지세탁기#트롬', '1056300', '961230', '0', '', '', '961230')

# %%
# 주어진 컬럼들을 바탕으로 ML 검색에 용이하도록 문맥에 맞게 병합

# 컬럼 인덱스 정의 (실제 CSV 파일의 컬럼 순서에 맞게 조정해야 합니다)
# 이 부분은 실제 데이터의 컬럼 순서와 일치해야 합니다.
COLUMN_INDICES = {
    "GOODS_NO": 0,
    "GOODS_NM": 1,
    "GOODS_STAT_SCT_NM": 2,
    "BRND_NM": 3,
    "ARTC_INFO": 4,
    "OPT_DISP_NM": 5,
    "OPT_VAL_DESC": 6,
    "CATEGORY_NMS": 7,
    "APPLIANCE_YN": 8,
    "SCH_KWD_NM": 9,
    "SALE_PRC": 10,
    "DSCNT_SALE_PRC": 11,
    "CARD_DC_RATE": 12,
    "CARD_DC_NAME": 13,
    "CARD_DC_NAME_LIST": 14,
    "MAX_BENEFIT_PRICE": 15
}

def generate_search_text_from_tuple(product_data_tuple):
    """
    주어진 상품 정보 튜플에서 검색에 최적화된 통합 텍스트 문자열을 생성합니다.
    머신러닝 기반의 의미론적 검색에 유리하도록 문맥을 구성합니다.

    Args:
        product_data_tuple (tuple): 상품 정보를 담고 있는 튜플.
                                  COLUMNS_INDICES에 정의된 순서와 일치해야 합니다.

    Returns:
        str: 검색 인덱싱을 위한 상품 정보를 결합한 문자열.
    """

    search_components = []

    # 튜플에서 데이터 추출 (COLUMN_INDICES를 활용하여 가독성을 높입니다)
    goods_nm = product_data_tuple[COLUMN_INDICES["GOODS_NM"]].strip()
    goods_stat_sct_nm = product_data_tuple[COLUMN_INDICES["GOODS_STAT_SCT_NM"]].strip()
    brnd_nm = product_data_tuple[COLUMN_INDICES["BRND_NM"]].strip()
    artc_info = product_data_tuple[COLUMN_INDICES["ARTC_INFO"]].strip()
    opt_disp_nm = product_data_tuple[COLUMN_INDICES["OPT_DISP_NM"]].strip()
    opt_val_desc = product_data_tuple[COLUMN_INDICES["OPT_VAL_DESC"]].strip()
    category_nms = product_data_tuple[COLUMN_INDICES["CATEGORY_NMS"]].strip()
    appliance_yn = product_data_tuple[COLUMN_INDICES["APPLIANCE_YN"]].strip()
    sch_kwd_nm = product_data_tuple[COLUMN_INDICES["SCH_KWD_NM"]].strip()
    
    # 숫자 값은 형 변환 시 에러 방지를 위해 get 대신 직접 접근 후 try-except 처리
    sale_prc_str = product_data_tuple[COLUMN_INDICES["SALE_PRC"]]
    dscnt_sale_prc_str = product_data_tuple[COLUMN_INDICES["DSCNT_SALE_PRC"]]
    card_dc_rate_str = product_data_tuple[COLUMN_INDICES["CARD_DC_RATE"]]
    max_benefit_price_str = product_data_tuple[COLUMN_INDICES["MAX_BENEFIT_PRICE"]]
    
    sale_prc = int(sale_prc_str) if sale_prc_str else None
    dscnt_sale_prc = int(dscnt_sale_prc_str) if dscnt_sale_prc_str else None
    card_dc_rate = int(card_dc_rate_str) if card_dc_rate_str else None
    max_benefit_price = int(max_benefit_price_str) if max_benefit_price_str else None

    card_dc_name = product_data_tuple[COLUMN_INDICES["CARD_DC_NAME"]].strip()


    # 1. 브랜드명 + 품목 정보 (카테고리/ARTC_INFO) + 상품명 조합
    # 상품의 핵심적인 정체성을 명확히 합니다.
    if brnd_nm and goods_nm:
        # ARTC_INFO에서 품목의 구체적인 타입을 추론하여 문맥에 더합니다.
        item_type = ''
        if artc_info:
            # '>' 기호로 구분된 품목 정보 중 가장 마지막 부분을 가져와 특정 품목 타입을 얻습니다.
            item_type_parts = [part.strip() for part in artc_info.split('>') if part.strip()]
            if item_type_parts:
                item_type = item_type_parts[-1]
                if '기타' in item_type: # '기타' 라는 모호한 품목이 포함되어 있는 경우
                    if category_nms: # 카테고리의 마지막 부분을 가져옵니다.
                        main_category_parts = [part.strip() for part in category_nms.split('>')]
                        if main_category_parts:
                            item_type = main_category_parts[0]


        # 품목 타입이 있고, 상품명에 이미 품목 타입이 포함되어 있지 않다면 추가합니다.
        if item_type and item_type not in goods_nm:
            search_components.append(f"{brnd_nm}의 {item_type}, {goods_nm}.")
        else: # 품목 타입이 없거나 상품명에 이미 포함되어 있다면 브랜드명과 상품명만 사용합니다.
            search_components.append(f"{brnd_nm}의 {goods_nm}.")
    elif goods_nm: # 브랜드명이 없는 경우 상품명만 사용합니다.
        search_components.append(f"{goods_nm}.")


    # 2. 제품의 주요 특성 (OPT_DISP_NM 및 OPT_VAL_DESC) 조합
    if opt_disp_nm and opt_val_desc:
        display_names = [name.strip() for name in opt_disp_nm.split(',') if name.strip()]
        values = [val.strip() for val in opt_val_desc.split(',') if val.strip()]

        # 각 특성 항목과 값을 '항목: 값' 형태로 결합합니다.
        characteristics = []
        for i in range(min(len(display_names), len(values))):
            # 비어있는 항목이나 '스마트기능'처럼 반복되는 용어는 건너뜁니다.
            # '스마트기능'이 반복되는 경우, 첫 번째 '스마트기능' 뒤에 모든 스마트기능 값을 나열합니다.
            if display_names[i] == '스마트기능':
                if i > 0 and display_names[i-1] == '스마트기능':
                    continue # 이미 처리되었으므로 건너뜁니다.
                
                # 모든 스마트기능 값을 모아서 처리
                all_smart_features = []
                for j in range(i, len(display_names)):
                    if display_names[j] == '스마트기능' and j < len(values):
                        all_smart_features.append(values[j])
                    else:
                        break # 스마트기능이 끝나면 반복 중단

                if all_smart_features:
                    characteristics.append(f"스마트기능: {', '.join(all_smart_features)}")
            else: # 일반적인 특성
                if display_names[i] and values[i]:
                    characteristics.append(f"{display_names[i]}: {values[i]}")

        if characteristics:
            search_components.append("주요 특징: " + ", ".join(characteristics) + ".")

    # 3. 카테고리명 추가
    if category_nms:
        # '|' 기호를 ', '로, '>' 기호를 ' > '로 바꾸어 카테고리 계층 및 다중 카테고리를 표현합니다.
        formatted_categories = category_nms.replace('|', ', ').replace('>', ' > ')
        search_components.append(f"카테고리: {formatted_categories}.")

    # 4. 상품 상태 추가
    if goods_stat_sct_nm and goods_stat_sct_nm != '정상상품': # '정상상품'이 아닌 경우에만 추가합니다.
        search_components.append(f"상품 상태: {goods_stat_sct_nm}.")

    # 5. 가격 및 할인 정보 추가
    price_info_components = []
    if sale_prc is not None:
        price_info_components.append(f"판매가 {sale_prc:,}원") # 천단위 콤마 추가
    if dscnt_sale_prc is not None and sale_prc is not None and dscnt_sale_prc < sale_prc:
        price_info_components.append(f"할인가 {dscnt_sale_prc:,}원") # 천단위 콤마 추가
    if card_dc_rate is not None and card_dc_rate > 0 and card_dc_name:
        if max_benefit_price is not None:
            price_info_components.append(f"{card_dc_name} 카드 사용 시 {card_dc_rate}% 할인되어 최대 {max_benefit_price:,}원") # 천단위 콤마 추가
        else:
            price_info_components.append(f"{card_dc_name} 카드 사용 시 {card_dc_rate}% 할인")

    if price_info_components:
        search_components.append("가격 정보: " + ", ".join(price_info_components) + ".")

    # 6. 가전제품 여부 추가
    if appliance_yn == 'Y':
        search_components.append("가전제품입니다.")
    else:
        search_components.append("가전제품이 아닙니다.")

    # 7. 해시태그 추가
    if sch_kwd_nm: 
        search_components.append(f"해시태그: {sch_kwd_nm}.")
    
    # 모든 구성 요소를 하나의 문자열로 결합하고 앞뒤 공백을 제거합니다.
    return " ".join(search_components).strip()

# %%
# 임베딩 텍스트 생성
for row in rows:
    search_text = generate_search_text_from_tuple(row)

search_text
# Out:
# 'LG전자의 LG 트롬 드럼 세탁기 24kg F24WDWP. 주요 특징: e효율등급: 1등급. 카테고리: 세탁기·건조기·의류관리기 > 드럼세탁기. 가격 정보: 판매가 1,056,300원, 할인가 961,230원. 가전제품입니다. 해시태그: #24kg#F24WDWP#LG#드럼#드럼세세탁기#세탁기#엘지세탁기#트롬.'
